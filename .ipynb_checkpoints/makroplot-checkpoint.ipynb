# %% [markdown]
# # Figurer og analyser av makroøkonomiske størrelser
#
# * Ansv. Joakim Blix Prestmo
# * Bidragsytere: Haakon Trønnes
# * Datakilder: SSB, ECB, NAV, FED, Norges Bank mv.
# * Siste oppdatering: 27. apr 2021

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
# import pandas_datareader.data as web

pd.options.display.max_columns=250
pd.options.display.max_rows=250

# %% [markdown]
# ## Endringer
# * Tatt inn månedstall

# %%
sns.__version__, pd.__version__
# Out:
# ('0.11.0', '1.1.3')

# %%
fastepriser = "2019-priser"
sistekvartal = "2020Q4"

# %% [markdown]
# <h2>Nasjonalregnskapstall</h2>

# %%
# Nasjonalregnskapet, faste priser, ses just og ujustert
dfses = pd.read_csv('http://data.ssb.no/api/v0/dataset/59022.csv?lang=no', encoding = 'latin1', na_values = '..', sep=";")
dfses  = dfses[dfses["statistikkvariabel"]=="Faste 2018-priser, sesongjustert (mill. kr)"]
dfses.drop('statistikkvariabel',1, inplace=True)
dfses['kvartal'] =pd.Series(dfses['kvartal']).str.replace('K', 'Q')
pd.to_datetime(dfses['kvartal'])
# 
dfses = dfses.pivot(index = 'kvartal', columns = 'makrostørrelse', values = '09190: Makroøkonomiske hovedstørrelser, etter makrostørrelse, kvartal og statistikkvariabel')

dfses.columns = [dfses.columns.str.split(' ')[i][0] for i in range(len(dfses.columns))]
kolonnenavn = list(dfses.columns.values)

# %%
url = 'https://www.ssb.no/statbank/sq/10035447'
dfmnd = pd.read_excel(url, skiprows=3, skipfooter=50)
dfmnd.rename(columns={'Unnamed: 0':'Dato', 'Konsum i husholdninger og ideelle organisasjoner': 'HushKonsum', 'Konsum i offentlig forvaltning': 'Offkonsum',
                     '¬¬¬ Næringer (bruttoinvestering)':'NaearingsInvest', '¬ Utvinning og rørtransport (bruttoinvestering)': 'OljeInvest', 
                     'Bruttonasjonalprodukt Fastlands-Norge, markedsverdi': 'BNPFN'}, inplace=True)
# dfmnd.drop(['Dato'], axis=1, inplace=True)
dfmnd.index=dfmnd['Dato']
dfmnd.drop(['Dato'], axis=1, inplace=True)

# %%
dfmnd.rename(columns={'Unnamed: 0':'Dato', 'Konsum i husholdninger og ideelle organisasjoner': 'HushKonsum', 'Konsum i offentlig forvaltning': 'OffKonsum',
                     '¬¬¬ Næringer (bruttoinvestering)':'NaearingsInvest', '¬ Utvinning og rørtransport (bruttoinvestering)': 'OljeInvest', 
                     'Bruttonasjonalprodukt Fastlands-Norge, markedsverdi': 'BNPFN'}, inplace=True)
# dfmnd.drop(['Dato'], axis=1, inplace=True)

# %%
# dfses.tail()
dfmnd.tail()
# Out:
#          HushKonsum  ¬ Konsum i husholdninger  ¬¬ Varekonsum  \
# Dato
# 2020M10      122168                    116069          61376
# 2020M11      120932                    114906          62829
# 2020M12      120665                    114761          62010
# 2021M01      117377                    111763          60453
# 2021M02      117085                    111607          60587
#
#          ¬¬ Tjenestekonsum  ¬¬ Husholdningenes kjøp i utlandet  \
# Dato
# 2020M10              55001                                 804
# 2020M11              52831                                 518
# 2020M12              52961                                 709
# 2021M01              51678                                 719
# 2021M02              51242                                 360
#
#          ¬¬ Utlendingers kjøp i Norge  ¬ Konsum i ideelle organisasjoner  \
# Dato
# 2020M10                         -1112                               6100
# 2020M11                         -1272                               6026
# 2020M12                          -919                               5904
# 2021M01                         -1087                               5614
# 2021M02                          -583                               5479
#
#          Offkonsum  ¬ Konsum i statsforvaltningen  \
# Dato
# 2020M10      72971                          36001
# 2020M11      73352                          36103
# 2020M12      74109                          36386
# 2021M01      72971                          35982
# 2021M02      72861                          35911
#
#          ¬¬¬ Konsum i statsforvaltningen, sivilt  \
# Dato
# 2020M10                                    31645
# 2020M11                                    31714
# 2020M12                                    32006
# 2021M01                                    31541
# 2021M02                                    31459
#
#          ¬¬¬ Konsum i statsforvaltningen, forsvar  \
# Dato
# 2020M10                                      4356
# 2020M11                                      4389
# 2020M12                                      4379
# 2021M01                                      4441
# 2021M02                                      4451
#
#          ¬ Konsum i kommuneforvaltningen  \
# Dato
# 2020M10                            36970
# 2020M11                            37249
# 2020M12                            37724
# 2021M01                            36989
# 2021M02                            36951
#
#          Bruttoinvestering i fast realkapital  OljeInvest  \
# Dato
# 2020M10                                 70834       13471
# 2020M11                                 70884       13321
# 2020M12                                 72363       14064
# 2021M01                                 70540       13520
# 2021M02                                 71320       13086
#
#          ¬ Utenriks sjøfart (bruttoinvestering)  \
# Dato
# 2020M10                                     152
# 2020M11                                    1122
# 2020M12                                      17
# 2021M01                                     323
# 2021M02                                    1341
#
#          ¬ Fastlands-Norge (bruttoinvestering)  \
# Dato
# 2020M10                                  57211
# 2020M11                                  56441
# 2020M12                                  58282
# 2021M01                                  56697
# 2021M02                                  56893
#
#          ¬¬ Fastlands-Norge utenom offentlig forvaltning (bruttoinvestering)  \
# Dato
# 2020M10                                              40372
# 2020M11                                              39898
# 2020M12                                              41407
# 2021M01                                              39706
# 2021M02                                              40488
#
#          NaearingsInvest  \
# Dato
# 2020M10            24891
# 2020M11            24390
# 2020M12            25419
# 2021M01            24598
# 2021M02            25053
#
#          ¬¬¬¬ Tjenester tilknyttet utvinning (bruttoinvestering)  \
# Dato
# 2020M10                                                141
# 2020M11                                                145
# 2020M12                                                147
# 2021M01                                                189
# 2021M02                                                199
#
#          ¬¬¬¬ Andre tjenester (bruttoinvestering)  \
# Dato
# 2020M10                                     15535
# 2020M11                                     15085
# 2020M12                                     15761
# 2021M01                                     14149
# 2021M02                                     14390
#
#          ¬¬¬¬ Industri og bergverk (bruttoinvestering)  \
# Dato
# 2020M10                                           3505
# 2020M11                                           3536
# 2020M12                                           3687
# 2021M01                                           4117
# 2021M02                                           4102
#
#          ¬¬¬¬ Annen vareproduksjon (bruttoinvestering)  \
# Dato
# 2020M10                                           5711
# 2020M11                                           5624
# 2020M12                                           5824
# 2021M01                                           6144
# 2021M02                                           6362
#
#          ¬¬¬ Boliger (husholdninger) (bruttoinvestering)  \
# Dato
# 2020M10                                            15481
# 2020M11                                            15508
# 2020M12                                            15988
# 2021M01                                            15108
# 2021M02                                            15435
#
#          ¬¬¬ Offentlig forvaltning (bruttoinvestering)  \
# Dato
# 2020M10                                          16839
# 2020M11                                          16543
# 2020M12                                          16876
# 2021M01                                          16990
# 2021M02                                          16405
#
#          Anskaffelser minus avhendelse av verdigjenstander  \
# Dato
# 2020M10                                                  5
# 2020M11                                                  4
# 2020M12                                                  8
# 2021M01                                                  3
# 2021M02                                                  5
#
#          Lagerendring og statistiske avvik  Bruttoinvestering i alt  \
# Dato
# 2020M10                               6517                    77355
# 2020M11                              13153                    84040
# 2020M12                               5155                    77526
# 2021M01                              11416                    81959
# 2021M02                               8856                    80182
#
#          Innenlandsk sluttanvendelse  \
# Dato
# 2020M10                       272495
# 2020M11                       278324
# 2020M12                       272300
# 2021M01                       272307
# 2021M02                       270128
#
#          Etterspørsel fra Fastlands-Norge (ekskl. lagerendring)  \
# Dato
# 2020M10                                             252350
# 2020M11                                             250725
# 2020M12                                             253057
# 2021M01                                             247045
# 2021M02                                             246840
#
#          Etterspørsel fra offentlig forvaltning  Eksport i alt  \
# Dato
# 2020M10                                   89810         114007
# 2020M11                                   89894         110830
# 2020M12                                   90985         116257
# 2021M01                                   89961         112104
# 2021M02                                   89266         112171
#
#          ¬ Tradisjonelle varer (eksport)  ¬ Råolje og naturgass (eksport)  \
# Dato
# 2020M10                            36811                            50578
# 2020M11                            35278                            48765
# 2020M12                            37565                            51736
# 2021M01                            36674                            47689
# 2021M02                            36420                            47792
#
#          ¬ Skip, plattformer og fly (eksport)  ¬ Tjenester (eksport)  \
# Dato
# 2020M10                                   100                  26519
# 2020M11                                   101                  26685
# 2020M12                                   585                  26370
# 2021M01                                   119                  27622
# 2021M02                                   721                  27238
#
#          Samlet sluttanvendelse  Import i alt  ¬ Tradisjonelle varer (import)  \
# Dato
# 2020M10                  386502         88392                           60324
# 2020M11                  389154         90727                           64140
# 2020M12                  388557         85531                           59334
# 2021M01                  384411         84016                           57043
# 2021M02                  382299         83989                           57714
#
#          ¬ Råolje og naturgass (import)  ¬ Skip, plattformer og fly (import)  \
# Dato
# 2020M10                            2339                                 2769
# 2020M11                            1519                                 2543
# 2020M12                            1364                                 1817
# 2021M01                            2119                                 1705
# 2021M02                             878                                 2284
#
#          ¬ Tjenester (import)  Bruttonasjonalprodukt, markedsverdi   BNPFN  \
# Dato
# 2020M10                 22960                               298110  249224
# 2020M11                 22525                               298427  247343
# 2020M12                 23016                               303027  250346
# 2021M01                 23149                               300396  248273
# 2021M02                 23114                               298310  246935
#
#          Oljevirksomhet og utenriks sjøfart  \
# Dato
# 2020M10                               48885
# 2020M11                               51085
# 2020M12                               52680
# 2021M01                               52122
# 2021M02                               51375
#
#          Bruttoprodukt Fastlands-Norge, basisverdi  \
# Dato
# 2020M10                                     215956
# 2020M11                                     214270
# 2020M12                                     216813
# 2021M01                                     216039
# 2021M02                                     214654
#
#          ¬ Fastlands-Norge utenom offentlig forvaltning (bruttoprodukt)  \
# Dato
# 2020M10                                             160675
# 2020M11                                             158616
# 2020M12                                             160535
# 2021M01                                             160271
# 2021M02                                             158947
#
#          ¬¬ Industri og bergverk (bruttoprodukt)  \
# Dato
# 2020M10                                    18533
# 2020M11                                    18785
# 2020M12                                    18843
# 2021M01                                    19202
# 2021M02                                    18835
#
#          ¬¬ Annen vareproduksjon (bruttoprodukt)  \
# Dato
# 2020M10                                    30972
# 2020M11                                    29479
# 2020M12                                    30979
# 2021M01                                    31207
# 2021M02                                    30570
#
#          ¬¬ Tjenester inkl. boligtjenester (bruttoprodukt)  \
# Dato
# 2020M10                                             111170
# 2020M11                                             110351
# 2020M12                                             110713
# 2021M01                                             109862
# 2021M02                                             109542
#
#          ¬ Offentlig forvaltning (bruttoprodukt)  \
# Dato
# 2020M10                                    55280
# 2020M11                                    55654
# 2020M12                                    56278
# 2021M01                                    55769
# 2021M02                                    55706
#
#          Produktavgifter og -subsidier
# Dato
# 2020M10                          33269
# 2020M11                          33073
# 2020M12                          33534
# 2021M01                          32234
# 2021M02                          32281

# %%
# pd.date_range(start='1/1/2000', end='30/09/2019', freq='Q')

# %%
dfses.tail()
# Out:
#          bif.nr8307  bif.nr8368  bif.nr83_6  bif.nr83_6fn  bif.nr83_6fnxof  \
# kvartal
# 2019Q4          961       46305      226617        179787           127093
# 2020Q1          772       45266      217705        172388           122494
# 2020Q2          707       45448      213508        172309           118166
# 2020Q3          611       44890      211705        170625           118032
# 2020Q4          429       47004      213592        172531           122007
#
#          bif.nr83indberg  bif.nr83naer  bif.nr83oljroer  bif.nr83rest  \
# kvartal
# 2019Q4             13145         80788            45910         47220
# 2020Q1             11823         77228            43398         46316
# 2020Q2             10948         72718            41021         42466
# 2020Q3             11136         73141            39717         43709
# 2020Q4             10908         75003            39771         46403
#
#          bif.nr83vare  bif.nr84_5  bif.nr8_  bif.pub8X50A  bil.nr8lu_  \
# kvartal
# 2019Q4          19462       52694    255430           920       28720
# 2020Q1          18317       49894    254149          1919       36359
# 2020Q2          18597       54144    232929           178       19410
# 2020Q3          17685       52594    244941          1362       33199
# 2020Q4          17263       50524    239533          1291       25924
#
#          biv.nr0890  bnpb.nr23_6fn  bnpb.nr23_6fnxof  bnpb.nr23_9  \
# kvartal
# 2019Q4           94         657630            492368       910476
# 2020Q1           85         645719            482726       897520
# 2020Q2           11         605889            449439       856237
# 2020Q3           38         634167            469987       894413
# 2020Q4           17         647402            480213       900102
#
#          bnpb.nr23_9fn  bnpb.nr23indberg  bnpb.nr23oljsj  bnpb.nr23ptjfn  \
# kvartal
# 2019Q4          757450             57138          153026          345454
# 2020Q1          742611             56408          154908          337121
# 2020Q2          698550             52892          157686          308879
# 2020Q3          733518             54202          160895          325654
# 2020Q4          747407             56146          152695          332448
#
#          bnpb.nr23vare  bnpb.nr24_5  bnpb.nr29korr  eks.nrskiplfly  \
# kvartal
# 2019Q4           89775       165262          99820            2008
# 2020Q1           89197       162994          96892            3264
# 2020Q2           87669       156450          92661            1647
# 2020Q3           90131       164180          99351            1851
# 2020Q4           91619       167189         100005             786
#
#          eks.nrtjen  eks.nrtot  eks.nrtradvare  eks.puboljegs  imp.nrskiplfly  \
# kvartal
# 2019Q4        93584     352347          108415         148340            6574
# 2020Q1        92971     346446          105561         144650            8217
# 2020Q2        74521     321017           97322         147526            8405
# 2020Q3        77288     335150          105471         150539            8578
# 2020Q4        79528     341202          109578         151309            7129
#
#          imp.nrtjen  imp.nrtot  imp.nrtradvare  imp.puboljegs  koh.nr61L8  \
# kvartal
# 2019Q4       107722     298464          176895           7273       29672
# 2020Q1        99938     288031          172601           7275       24875
# 2020Q2        64951     238746          160248           5142         673
# 2020Q3        69911     263836          180526           4820        3757
# 2020Q4        68473     264602          183832           5168        2081
#
#          koh.nr61L9  koh.nr61_  koh.nr61tjen  koh.nr61vare  koh.nrpriv  \
# kvartal
# 2019Q4       -13113     367855        183719        167577      388780
# 2020Q1       -10690     351867        173842        163839      372035
# 2020Q2        -1136     316115        142826        173752      332681
# 2020Q3        -2230     345798        160335        183937      363684
# 2020Q4        -3208     345453        161321        185258      363507
#
#          koi.nr66_  koo.nr6401  koo.nr64_  koo.nr64sivil  koo.nr65_  \
# kvartal
# 2019Q4       20926       12754     103849          91095     108534
# 2020Q1       20167       12713     105177          92464     107743
# 2020Q2       16565       12834     102877          90042     105479
# 2020Q3       17886       12985     105952          92967     108522
# 2020Q4       18054       13125     108480          95355     111981
#
#          koo.nroff  makrok.nrefn  makrok.nreoff  makrok.nrianv  makrok.nrsanv
# kvartal
# 2019Q4      212383        780950         265076         856593        1208940
# 2020Q1      212921        757343         262814         839104        1185550
# 2020Q2      208356        713346         262500         773966        1094983
# 2020Q3      214474        748783         267067         823099        1158249
# 2020Q4      220461        756499         270985         823502        1164704

# %%
# date_rng
#  https://towardsdatascience.com/basic-time-series-manipulation-with-pandas-4432afee64ea

# %%
dfses['bnpb.nr23_9fn'].tail()

dfses['log_BNP'] = np.log(dfses['bnpb.nr23_9fn'])
dfses['Glog_BNP'] = dfses['log_BNP'].rolling(window=7, center=True).mean()
dfses['Dlog_BNP'] = (dfses['log_BNP']).diff()
dfses['D4log_BNP'] = dfses['log_BNP'].diff(4)
dfses['DBNP-trend'] = dfses['Dlog_BNP']['1998K1':sistekvartal].mean()
dfses['GDlog_BNP'] = dfses['Dlog_BNP'].rolling(window=7, center=True).mean()
dfses['BNP-gap'] = (dfses['GDlog_BNP']/dfses['DBNP-trend']-1)

# dfses['Glog_BNP'] = dfses['log_BNP'].rolling(window=25).mean()

# %%
import pickle
dfses.to_pickle('../dfses.pkl')
# dfses = pd.read_pickle('../dfses.pkl')

# %%
dfses.tail()
# Out:
#          bif.nr8307  bif.nr8368  bif.nr83_6  bif.nr83_6fn  bif.nr83_6fnxof  \
# kvartal
# 2019Q4          961       46305      226617        179787           127093
# 2020Q1          772       45266      217705        172388           122494
# 2020Q2          707       45448      213508        172309           118166
# 2020Q3          611       44890      211705        170625           118032
# 2020Q4          429       47004      213592        172531           122007
#
#          bif.nr83indberg  bif.nr83naer  bif.nr83oljroer  bif.nr83rest  \
# kvartal
# 2019Q4             13145         80788            45910         47220
# 2020Q1             11823         77228            43398         46316
# 2020Q2             10948         72718            41021         42466
# 2020Q3             11136         73141            39717         43709
# 2020Q4             10908         75003            39771         46403
#
#          bif.nr83vare  bif.nr84_5  bif.nr8_  bif.pub8X50A  bil.nr8lu_  \
# kvartal
# 2019Q4          19462       52694    255430           920       28720
# 2020Q1          18317       49894    254149          1919       36359
# 2020Q2          18597       54144    232929           178       19410
# 2020Q3          17685       52594    244941          1362       33199
# 2020Q4          17263       50524    239533          1291       25924
#
#          biv.nr0890  bnpb.nr23_6fn  bnpb.nr23_6fnxof  bnpb.nr23_9  \
# kvartal
# 2019Q4           94         657630            492368       910476
# 2020Q1           85         645719            482726       897520
# 2020Q2           11         605889            449439       856237
# 2020Q3           38         634167            469987       894413
# 2020Q4           17         647402            480213       900102
#
#          bnpb.nr23_9fn  bnpb.nr23indberg  bnpb.nr23oljsj  bnpb.nr23ptjfn  \
# kvartal
# 2019Q4          757450             57138          153026          345454
# 2020Q1          742611             56408          154908          337121
# 2020Q2          698550             52892          157686          308879
# 2020Q3          733518             54202          160895          325654
# 2020Q4          747407             56146          152695          332448
#
#          bnpb.nr23vare  bnpb.nr24_5  bnpb.nr29korr  eks.nrskiplfly  \
# kvartal
# 2019Q4           89775       165262          99820            2008
# 2020Q1           89197       162994          96892            3264
# 2020Q2           87669       156450          92661            1647
# 2020Q3           90131       164180          99351            1851
# 2020Q4           91619       167189         100005             786
#
#          eks.nrtjen  eks.nrtot  eks.nrtradvare  eks.puboljegs  imp.nrskiplfly  \
# kvartal
# 2019Q4        93584     352347          108415         148340            6574
# 2020Q1        92971     346446          105561         144650            8217
# 2020Q2        74521     321017           97322         147526            8405
# 2020Q3        77288     335150          105471         150539            8578
# 2020Q4        79528     341202          109578         151309            7129
#
#          imp.nrtjen  imp.nrtot  imp.nrtradvare  imp.puboljegs  koh.nr61L8  \
# kvartal
# 2019Q4       107722     298464          176895           7273       29672
# 2020Q1        99938     288031          172601           7275       24875
# 2020Q2        64951     238746          160248           5142         673
# 2020Q3        69911     263836          180526           4820        3757
# 2020Q4        68473     264602          183832           5168        2081
#
#          koh.nr61L9  koh.nr61_  koh.nr61tjen  koh.nr61vare  koh.nrpriv  \
# kvartal
# 2019Q4       -13113     367855        183719        167577      388780
# 2020Q1       -10690     351867        173842        163839      372035
# 2020Q2        -1136     316115        142826        173752      332681
# 2020Q3        -2230     345798        160335        183937      363684
# 2020Q4        -3208     345453        161321        185258      363507
#
#          koi.nr66_  koo.nr6401  koo.nr64_  koo.nr64sivil  koo.nr65_  \
# kvartal
# 2019Q4       20926       12754     103849          91095     108534
# 2020Q1       20167       12713     105177          92464     107743
# 2020Q2       16565       12834     102877          90042     105479
# 2020Q3       17886       12985     105952          92967     108522
# 2020Q4       18054       13125     108480          95355     111981
#
#          koo.nroff  makrok.nrefn  makrok.nreoff  makrok.nrianv  makrok.nrsanv  \
# kvartal
# 2019Q4      212383        780950         265076         856593        1208940
# 2020Q1      212921        757343         262814         839104        1185550
# 2020Q2      208356        713346         262500         773966        1094983
# 2020Q3      214474        748783         267067         823099        1158249
# 2020Q4      220461        756499         270985         823502        1164704
#
#            log_BNP   Glog_BNP  Dlog_BNP  D4log_BNP  DBNP-trend  GDlog_BNP  \
# kvartal
# 2019Q4   13.537713  13.515846  0.000131   0.017324    0.005201  -0.002112
# 2020Q1   13.517928  13.515801 -0.019785  -0.006748    0.005201  -0.000044
# 2020Q2   13.456762        NaN -0.061166  -0.073890    0.005201        NaN
# 2020Q3   13.505607        NaN  0.048845  -0.031975    0.005201        NaN
# 2020Q4   13.524365        NaN  0.018758  -0.013348    0.005201        NaN
#
#           BNP-gap
# kvartal
# 2019Q4  -1.406007
# 2020Q1  -1.008525
# 2020Q2        NaN
# 2020Q3        NaN
# 2020Q4        NaN

# %%
dfmnd.tail(12)
# Out:
#          HushKonsum  ¬ Konsum i husholdninger  ¬¬ Varekonsum  \
# Dato
# 2020M01      128790                    121838          54621
# 2020M02      129913                    122874          55763
# 2020M03      113331                    107156          53454
# 2020M04      104344                     98905          55149
# 2020M05      110276                    104875          57753
# 2020M06      118061                    112336          60850
# 2020M07      121897                    115988          62896
# 2020M08      119931                    113941          59341
# 2020M09      121856                    115868          61700
# 2020M10      122130                    116029          61134
# 2020M11      120716                    114690          62396
# 2020M12      120661                    114734          61728
#
#          ¬¬ Tjenestekonsum  ¬¬ Husholdningenes kjøp i utlandet  \
# Dato
# 2020M01              61481                               10189
# 2020M02              61246                               10193
# 2020M03              51115                                4493
# 2020M04              44043                                 115
# 2020M05              47349                                 154
# 2020M06              51433                                 404
# 2020M07              52471                                1295
# 2020M08              53765                                1597
# 2020M09              54098                                 864
# 2020M10              55159                                 819
# 2020M11              52994                                 535
# 2020M12              53168                                 727
#
#          ¬¬ Utlendingers kjøp i Norge  ¬ Konsum i ideelle organisasjoner  \
# Dato
# 2020M01                         -4455                               6952
# 2020M02                         -4328                               7039
# 2020M03                         -1907                               6176
# 2020M04                          -403                               5440
# 2020M05                          -381                               5401
# 2020M06                          -352                               5725
# 2020M07                          -674                               5909
# 2020M08                          -762                               5990
# 2020M09                          -794                               5988
# 2020M10                         -1083                               6101
# 2020M11                         -1235                               6026
# 2020M12                          -890                               5928
#
#          Offkonsum  ¬ Konsum i statsforvaltningen  \
# Dato
# 2020M01      71507                          35468
# 2020M02      71380                          35380
# 2020M03      70033                          34329
# 2020M04      68709                          33616
# 2020M05      69366                          34024
# 2020M06      70280                          35236
# 2020M07      70912                          35070
# 2020M08      71744                          35385
# 2020M09      71818                          35497
# 2020M10      72887                          36006
# 2020M11      73261                          36101
# 2020M12      74313                          36373
#
#          ¬¬¬ Konsum i statsforvaltningen, sivilt  \
# Dato
# 2020M01                                    31239
# 2020M02                                    31134
# 2020M03                                    30091
# 2020M04                                    29347
# 2020M05                                    29759
# 2020M06                                    30937
# 2020M07                                    30768
# 2020M08                                    31054
# 2020M09                                    31144
# 2020M10                                    31650
# 2020M11                                    31712
# 2020M12                                    31994
#
#          ¬¬¬ Konsum i statsforvaltningen, forsvar  \
# Dato
# 2020M01                                      4229
# 2020M02                                      4245
# 2020M03                                      4238
# 2020M04                                      4270
# 2020M05                                      4265
# 2020M06                                      4300
# 2020M07                                      4302
# 2020M08                                      4330
# 2020M09                                      4353
# 2020M10                                      4356
# 2020M11                                      4389
# 2020M12                                      4379
#
#          ¬ Konsum i kommuneforvaltningen  \
# Dato
# 2020M01                            36039
# 2020M02                            36000
# 2020M03                            35704
# 2020M04                            35093
# 2020M05                            35342
# 2020M06                            35044
# 2020M07                            35842
# 2020M08                            36359
# 2020M09                            36321
# 2020M10                            36881
# 2020M11                            37160
# 2020M12                            37941
#
#          Bruttoinvestering i fast realkapital  OljeInvest  \
# Dato
# 2020M01                                 72311       14662
# 2020M02                                 73745       14282
# 2020M03                                 71649       14453
# 2020M04                                 69861       13857
# 2020M05                                 71981       13685
# 2020M06                                 71666       13478
# 2020M07                                 69650       13367
# 2020M08                                 69778       13362
# 2020M09                                 72277       12987
# 2020M10                                 70960       13440
# 2020M11                                 71032       13285
# 2020M12                                 71599       13046
#
#          ¬ Utenriks sjøfart (bruttoinvestering)  \
# Dato
# 2020M01                                     326
# 2020M02                                    1576
# 2020M03                                      18
# 2020M04                                    -195
# 2020M05                                      12
# 2020M06                                     361
# 2020M07                                      44
# 2020M08                                    1304
# 2020M09                                      14
# 2020M10                                     152
# 2020M11                                    1122
# 2020M12                                      17
#
#          ¬ Fastlands-Norge (bruttoinvestering)  \
# Dato
# 2020M01                                  57323
# 2020M02                                  57887
# 2020M03                                  57178
# 2020M04                                  56198
# 2020M05                                  58283
# 2020M06                                  57827
# 2020M07                                  56238
# 2020M08                                  55111
# 2020M09                                  59276
# 2020M10                                  57369
# 2020M11                                  56625
# 2020M12                                  58537
#
#          ¬¬ Fastlands-Norge utenom offentlig forvaltning (bruttoinvestering)  \
# Dato
# 2020M01                                              40645
# 2020M02                                              41173
# 2020M03                                              40676
# 2020M04                                              38617
# 2020M05                                              39426
# 2020M06                                              40122
# 2020M07                                              39251
# 2020M08                                              38073
# 2020M09                                              40708
# 2020M10                                              40462
# 2020M11                                              39998
# 2020M12                                              41547
#
#          NaearingsInvest  \
# Dato
# 2020M01            25808
# 2020M02            26252
# 2020M03            25168
# 2020M04            23634
# 2020M05            24164
# 2020M06            24920
# 2020M07            24002
# 2020M08            23436
# 2020M09            25703
# 2020M10            24973
# 2020M11            24481
# 2020M12            25548
#
#          ¬¬¬¬ Tjenester tilknyttet utvinning (bruttoinvestering)  \
# Dato
# 2020M01                                                252
# 2020M02                                                267
# 2020M03                                                253
# 2020M04                                                239
# 2020M05                                                232
# 2020M06                                                236
# 2020M07                                                201
# 2020M08                                                203
# 2020M09                                                206
# 2020M10                                                140
# 2020M11                                                144
# 2020M12                                                145
#
#          ¬¬¬¬ Andre tjenester (bruttoinvestering)  \
# Dato
# 2020M01                                     15610
# 2020M02                                     15702
# 2020M03                                     15004
# 2020M04                                     13664
# 2020M05                                     14118
# 2020M06                                     14685
# 2020M07                                     14025
# 2020M08                                     13870
# 2020M09                                     15815
# 2020M10                                     15528
# 2020M11                                     15077
# 2020M12                                     15798
#
#          ¬¬¬¬ Industri og bergverk (bruttoinvestering)  \
# Dato
# 2020M01                                           3895
# 2020M02                                           3981
# 2020M03                                           3947
# 2020M04                                           3627
# 2020M05                                           3631
# 2020M06                                           3690
# 2020M07                                           3688
# 2020M08                                           3686
# 2020M09                                           3761
# 2020M10                                           3559
# 2020M11                                           3606
# 2020M12                                           3743
#
#          ¬¬¬¬ Annen vareproduksjon (bruttoinvestering)  \
# Dato
# 2020M01                                           6050
# 2020M02                                           6302
# 2020M03                                           5964
# 2020M04                                           6104
# 2020M05                                           6183
# 2020M06                                           6310
# 2020M07                                           6087
# 2020M08                                           5677
# 2020M09                                           5921
# 2020M10                                           5746
# 2020M11                                           5655
# 2020M12                                           5862
#
#          ¬¬¬ Boliger (husholdninger) (bruttoinvestering)  \
# Dato
# 2020M01                                            14837
# 2020M02                                            14921
# 2020M03                                            15508
# 2020M04                                            14983
# 2020M05                                            15262
# 2020M06                                            15202
# 2020M07                                            15249
# 2020M08                                            14637
# 2020M09                                            15004
# 2020M10                                            15488
# 2020M11                                            15518
# 2020M12                                            15998
#
#          ¬¬¬ Offentlig forvaltning (bruttoinvestering)  \
# Dato
# 2020M01                                          16677
# 2020M02                                          16715
# 2020M03                                          16502
# 2020M04                                          17581
# 2020M05                                          18857
# 2020M06                                          17705
# 2020M07                                          16988
# 2020M08                                          17038
# 2020M09                                          18568
# 2020M10                                          16907
# 2020M11                                          16627
# 2020M12                                          16990
#
#          Anskaffelser minus avhendelse av verdigjenstander  \
# Dato
# 2020M01                                                 34
# 2020M02                                                 33
# 2020M03                                                 18
# 2020M04                                                  4
# 2020M05                                                  4
# 2020M06                                                  4
# 2020M07                                                 19
# 2020M08                                                 11
# 2020M09                                                  8
# 2020M10                                                  5
# 2020M11                                                  4
# 2020M12                                                  9
#
#          Lagerendring og statistiske avvik  Bruttoinvestering i alt  \
# Dato
# 2020M01                              15637                    87982
# 2020M02                              12195                    85974
# 2020M03                               8527                    80194
# 2020M04                               5792                    75657
# 2020M05                               4779                    76763
# 2020M06                               8839                    80510
# 2020M07                               7450                    77119
# 2020M08                              15602                    85391
# 2020M09                              10147                    82431
# 2020M10                               6651                    77617
# 2020M11                              13801                    84837
# 2020M12                               5472                    77080
#
#          Innenlandsk sluttanvendelse  \
# Dato
# 2020M01                       288279
# 2020M02                       287267
# 2020M03                       263558
# 2020M04                       248710
# 2020M05                       256404
# 2020M06                       268851
# 2020M07                       269928
# 2020M08                       277066
# 2020M09                       276105
# 2020M10                       272634
# 2020M11                       278814
# 2020M12                       272054
#
#          Etterspørsel fra Fastlands-Norge (ekskl. lagerendring)  \
# Dato
# 2020M01                                             257620
# 2020M02                                             259180
# 2020M03                                             240543
# 2020M04                                             229252
# 2020M05                                             237925
# 2020M06                                             246168
# 2020M07                                             249048
# 2020M08                                             246786
# 2020M09                                             252949
# 2020M10                                             252386
# 2020M11                                             250602
# 2020M12                                             253512
#
#          Etterspørsel fra offentlig forvaltning  Eksport i alt  \
# Dato
# 2020M01                                   88185         114362
# 2020M02                                   88094         116762
# 2020M03                                   86535         115322
# 2020M04                                   86291         106804
# 2020M05                                   88223         105663
# 2020M06                                   87986         108550
# 2020M07                                   87900         111954
# 2020M08                                   88782         110780
# 2020M09                                   90386         112416
# 2020M10                                   89794         114009
# 2020M11                                   89888         110828
# 2020M12                                   91303         116365
#
#          ¬ Tradisjonelle varer (eksport)  ¬ Råolje og naturgass (eksport)  \
# Dato
# 2020M01                            34937                            46318
# 2020M02                            35716                            49241
# 2020M03                            34909                            49091
# 2020M04                            33570                            48430
# 2020M05                            31954                            48779
# 2020M06                            31799                            50317
# 2020M07                            33755                            51389
# 2020M08                            35594                            48967
# 2020M09                            36122                            50182
# 2020M10                            36812                            50600
# 2020M11                            35233                            48832
# 2020M12                            37532                            51878
#
#          ¬ Skip, plattformer og fly (eksport)  ¬ Tjenester (eksport)  \
# Dato
# 2020M01                                  1240                  31867
# 2020M02                                   106                  31700
# 2020M03                                  1918                  29404
# 2020M04                                   368                  24436
# 2020M05                                   439                  24491
# 2020M06                                   840                  25595
# 2020M07                                  1250                  25559
# 2020M08                                   468                  25750
# 2020M09                                   132                  25979
# 2020M10                                   100                  26498
# 2020M11                                   101                  26661
# 2020M12                                   585                  26370
#
#          Samlet sluttanvendelse  Import i alt  ¬ Tradisjonelle varer (import)  \
# Dato
# 2020M01                  402641         99909                           58972
# 2020M02                  404029         99151                           58220
# 2020M03                  378880         88970                           55409
# 2020M04                  355514         76368                           51491
# 2020M05                  362068         77142                           51031
# 2020M06                  377401         85236                           57726
# 2020M07                  381882         86623                           60346
# 2020M08                  387846         89285                           60627
# 2020M09                  388521         87928                           59553
# 2020M10                  386643         88423                           60346
# 2020M11                  389641         90761                           64196
# 2020M12                  388420         85418                           59290
#
#          ¬ Råolje og naturgass (import)  ¬ Skip, plattformer og fly (import)  \
# Dato
# 2020M01                            2855                                 2651
# 2020M02                            2465                                 2938
# 2020M03                            1955                                 2628
# 2020M04                            2037                                 1305
# 2020M05                            1376                                 3404
# 2020M06                            1728                                 3696
# 2020M07                            1125                                 1640
# 2020M08                            1933                                 3177
# 2020M09                            1761                                 3761
# 2020M10                            2326                                 2769
# 2020M11                            1500                                 2543
# 2020M12                            1343                                 1817
#
#          ¬ Tjenester (import)  Bruttonasjonalprodukt, markedsverdi   BNPFN  \
# Dato
# 2020M01                 35432                               302732  252301
# 2020M02                 35528                               304877  253131
# 2020M03                 28978                               289910  237180
# 2020M04                 21536                               279146  226482
# 2020M05                 21330                               284925  232434
# 2020M06                 22085                               292165  239635
# 2020M07                 23512                               295258  242277
# 2020M08                 23547                               298561  244792
# 2020M09                 22852                               300593  246448
# 2020M10                 22982                               298220  249333
# 2020M11                 22522                               298880  247773
# 2020M12                 22968                               303002  250301
#
#          Oljevirksomhet og utenriks sjøfart  \
# Dato
# 2020M01                               50432
# 2020M02                               51747
# 2020M03                               52730
# 2020M04                               52665
# 2020M05                               52491
# 2020M06                               52530
# 2020M07                               52981
# 2020M08                               53769
# 2020M09                               54145
# 2020M10                               48887
# 2020M11                               51107
# 2020M12                               52701
#
#          Bruttoprodukt Fastlands-Norge, basisverdi  \
# Dato
# 2020M01                                     219357
# 2020M02                                     219980
# 2020M03                                     206383
# 2020M04                                     196795
# 2020M05                                     201547
# 2020M06                                     207547
# 2020M07                                     208876
# 2020M08                                     212082
# 2020M09                                     213209
# 2020M10                                     215850
# 2020M11                                     214183
# 2020M12                                     217368
#
#          ¬ Fastlands-Norge utenom offentlig forvaltning (bruttoprodukt)  \
# Dato
# 2020M01                                             163833
# 2020M02                                             164567
# 2020M03                                             154326
# 2020M04                                             146584
# 2020M05                                             149515
# 2020M06                                             153341
# 2020M07                                             154727
# 2020M08                                             157164
# 2020M09                                             158096
# 2020M10                                             160581
# 2020M11                                             158549
# 2020M12                                             161082
#
#          ¬¬ Industri og bergverk (bruttoprodukt)  \
# Dato
# 2020M01                                    18969
# 2020M02                                    19034
# 2020M03                                    18405
# 2020M04                                    17856
# 2020M05                                    17609
# 2020M06                                    17428
# 2020M07                                    17510
# 2020M08                                    18522
# 2020M09                                    18170
# 2020M10                                    18530
# 2020M11                                    18776
# 2020M12                                    18840
#
#          ¬¬ Annen vareproduksjon (bruttoprodukt)  \
# Dato
# 2020M01                                    29821
# 2020M02                                    30203
# 2020M03                                    29173
# 2020M04                                    28944
# 2020M05                                    29303
# 2020M06                                    29421
# 2020M07                                    30324
# 2020M08                                    29776
# 2020M09                                    30031
# 2020M10                                    30942
# 2020M11                                    29481
# 2020M12                                    31196
#
#          ¬¬ Tjenester inkl. boligtjenester (bruttoprodukt)  \
# Dato
# 2020M01                                             115042
# 2020M02                                             115330
# 2020M03                                             106749
# 2020M04                                              99784
# 2020M05                                             102603
# 2020M06                                             106491
# 2020M07                                             106893
# 2020M08                                             108866
# 2020M09                                             109895
# 2020M10                                             111110
# 2020M11                                             110292
# 2020M12                                             111047
#
#          ¬ Offentlig forvaltning (bruttoprodukt)  \
# Dato
# 2020M01                                    55524
# 2020M02                                    55413
# 2020M03                                    52057
# 2020M04                                    50212
# 2020M05                                    52032
# 2020M06                                    54207
# 2020M07                                    54149
# 2020M08                                    54919
# 2020M09                                    55113
# 2020M10                                    55269
# 2020M11                                    55634
# 2020M12                                    56286
#
#          Produktavgifter og -subsidier
# Dato
# 2020M01                          32944
# 2020M02                          33151
# 2020M03                          30797
# 2020M04                          29687
# 2020M05                          30887
# 2020M06                          32087
# 2020M07                          33401
# 2020M08                          32710
# 2020M09                          33239
# 2020M10                          33483
# 2020M11                          33590
# 2020M12                          32932

# %%
dfmnd['HushKonsum'].tail()
print((113145-128195)/128195*100)
# Out:
# -11.739927454268887

# %%
# Figur konsum i husholdningene, ses. just månedstall

(dfmnd['HushKonsum']/1000).plot()
# dfmnd['OljeInvest'].plot()
# dfmnd['Offkonsum'].plot()
plt.title('25 pst fall i husholdningenes konsum i vår, konsumet fortsatt ikke tilbake')
# plt.rc('text', usetex=True)
plt.ylabel('Mill. 2018-kr')
plt.xlabel('Månedlige tall. I faste 2018-priser, sesongjustert')
plt.savefig('../Figurer/Makro/konsumMnd.png')
plt.show()

# %%
# Figur konsum i husholdningene, ses. just månedstall

(dfmnd['OljeInvest']/1000).plot()
# dfmnd['OljeInvest'].plot()
# dfmnd['Offkonsum'].plot()
plt.title('Klar nedgang i oljeinvesteringene, men fortsatt over 2017-nivået')
# plt.rc('text', usetex=True)
plt.ylabel('Mill. 2018-kr')
plt.xlabel('Månedlige tall. I faste 2018-priser, sesongjustert')
plt.savefig('../Figurer/Makro/oljeInvestMnd.png')
plt.show()

# %%
# 1.12 BNP sesjustert
#['2008K2':'2017K3']
plt.clf()
dfses['bnpb.nr23_9'].plot(label = 'Bruttonasjonalprodukt')
dfses['bnpb.nr23_9fn'].plot(label = 'Bruttonasjonalprodukt Fastlands-Norge')
# dfses['Glog_BNP'].plot()
# dfses['log_BNP'].plot()

plt.title('BNP, milloner faste '+fastepriser)
plt.ylabel('MNOK')
plt.xlabel("Tid")

plt.legend(bbox_to_anchor=(0.2, -0.2), loc=3,
           ncol=2, mode="expand", borderaxespad=0., fancybox=True )
plt.savefig('1.12 BNP.png')
plt.show()

#,bbox_inches="tight"

# %%
# 1.13 BNP sesjustert vekst

#dfses['Dlog_BNP']['2008K2':'2017K3'].plot(label = 'Bruttonasjonalprodukt Fastlands-Norge')
#dfses['GDlog_BNP']['2008K2':'2017K3'].plot(label='Trendvekst')
dfses['BNP-gap']['2002Q1':sistekvartal].plot(label='BNP-gap')
plt.title('Produksjonsgap. Avvik fra trendvekst i prosent ')
plt.ylabel('Prosent')
plt.xlabel('')
plt.legend(bbox_to_anchor=(0.3, -0.15), loc=3,
           ncol=2, mode="expand", borderaxespad=0., fancybox=True )
#plt.legend()
plt.savefig('../Figurer/Makro/1.13 BNP-gap.png')
plt.show()

# %%
# kolonnenavn

# %%
plt.clf()

#1.22 Investering
dfses['bif.nr83naer']['2008K2':sistekvartal].plot(label = 'Næringer')
dfses['bif.nr8368']['2008K2':sistekvartal].plot(label = 'Boliger (husholdninger)')
dfses['bif.nr83oljroer']['2008K2':sistekvartal].plot(label = 'Utvinning og rørtransport')
# dfses['bif.nr83indberg']['2008K2':sistekvartal].plot(label = 'Industri') 
# dfses['bif.nr83rest']['2008K2':sistekvartal].plot(label = 'Andre tjenester') 
# dfses['bif.nr83vare']['2008K2':sistekvartal].plot(label = 'Annen vareproduksjon') 
dfses['bif.nr84_5']['2008K2':sistekvartal].plot(label = 'Offentlig forvaltning')
plt.title('Investeringer i Norge. Faste '+fastepriser+', sesongjustert')
plt.ylabel('MNOK')
plt.legend()
plt.savefig('../Figurer/Makro/1.22 Investering.png')

# %%
plt.clf()

#1.23 Andre investering
dfses['bif.nr83indberg']['2015K1':sistekvartal].plot(label = 'Industri') 
dfses['bif.nr83rest']['2015K1':sistekvartal].plot(label = 'Andre tjenester') 
dfses['bif.nr83vare']['2015K1':sistekvartal].plot(label = 'Annen vareproduksjon') 
plt.title('Investeringer i Norge. Faste '+fastepriser+', sesongjustert')
plt.ylabel('MNOK')
plt.legend()
plt.savefig('../Figurer/Makro/1.23 Andre ivestering.png')

# %%
plt.clf()
#1.31 økosirk
#df['bnpb.nr23_9'].plot(label = 'Bruttonasjonalprodukt, markedsverdi')
#df['imp.nrtot'].plot(label = 'Im')#(label = 'Import i alt')
plt.clf()
dfses['bif.nr8_']['2005K3':'2019Q3'].plot(label = 'I')#(label = 'Bruttoinvestering i alt')
dfses['koh.nrpriv']['2005K3':'2019Q3'].plot(label = 'C')#(label = 'Konsum i husholdninger og ideelle organisasjoner')
(dfses['eks.nrtot']['2005K3':'2019Q3']-dfses['imp.nrtot']['2005K3':'2019K1']).plot(label = 'NX')#(label = 'Eksport i alt')
dfses['makrok.nreoff']['2005K3':'2019Q3'].plot(label = 'G')#(label = 'Etterspørsel fra offentlig forvaltning')
plt.ylabel('MNOK')
plt.xlabel('')
#plt.legend()
plt.legend(bbox_to_anchor=(0., -0.15, 1, 0.25), loc=4,
           ncol=4, mode="expand", borderaxespad=0., fancybox=False )
plt.title("Hovedstørrelser, Faste "+fastepriser+", sesongjustert")
plt.savefig('1.31 Økosirk.png')

# %%
# vekst fra forrige kvartal
DI = np.log(dfses['bif.nr8_']).diff()*100
DC = np.log(dfses['koh.nrpriv']).diff()*100
DX = np.log(dfses['eks.nrtot']).diff()*100
DNX = np.log(dfses['eks.nrtot']-dfses['imp.nrtot']+5000).diff()
D4G = np.log(dfses['makrok.nreoff']).diff(4)*25
D4I = np.log(dfses['bif.nr8_']).diff(4)*25
D4C = np.log(dfses['koh.nrpriv']).diff(4)*25

I_index = dfses['bif.nr8_']/dfses['bif.nr8_']['2017Q1']
C_index = dfses['koh.nrpriv']/dfses['koh.nrpriv']['2017Q1']
NX_index = (dfses['eks.nrtot']-dfses['imp.nrtot'])/(dfses['eks.nrtot']['2017Q1']-dfses['imp.nrtot']['2017Q1'])
G_index = dfses['makrok.nreoff']/dfses['makrok.nreoff']['2017Q1']
X_index = dfses['eks.nrtot']/dfses['eks.nrtot']['2017Q1']

# %%
#1.32 økosirk - indeksert
#df['bnpb.nr23_9'].plot(label = 'Bruttonasjonalprodukt, markedsverdi')
#df['imp.nrtot'].plot(label = 'Im')#(label = 'Import i alt')
I_index['2010Q1':].plot(label = 'I')#(label = 'Bruttoinvestering i alt')
C_index['2010Q':].plot(label = 'C')#(label = 'Konsum i husholdninger og ideelle organisasjoner')
# X_index['2010Q':].plot(label = 'X')#(label = 'Eksport i alt')
# NX_index['2010Q':].plot(label = 'NX')#(label = 'Eksport i alt')
G_index['2010K1':].plot(label = 'G')#(label = 'Etterspørsel fra offentlig forvaltning')
plt.ylabel('Prosent')
plt.title('Hovedstørrelser. Faste '+fastepriser+', sesongjustert og indeksert')
plt.legend()
plt.savefig('1.32 Økosirk.png')

# %%
plt.clf()
#1.32 økosirk - vekst
#df['bnpb.nr23_9'].plot(label = 'Bruttonasjonalprodukt, markedsverdi')
#df['imp.nrtot'].plot(label = 'Im')#(label = 'Import i alt')
# D4I['2012Q1':sistekvartal].plot(label = 'I')#(label = 'Bruttoinvestering i alt')
D4C['2010Q1':sistekvartal].plot(label = 'C')#(label = 'Konsum i husholdninger og ideelle organisasjoner')
# DNX['2010K1':sistekvartal].plot(label = 'NX')#(label = 'Eksport i alt')
D4G['2010Q1':sistekvartal].plot(label = 'G')#(label = 'Etterspørsel fra offentlig forvaltning')
plt.ylabel('Prosent')
plt.xlabel('Kvartal')
plt.title('Vekst i hovedstørrelser fra samme kvartal året før. Faste '+fastepriser+'')
plt.legend()
plt.savefig('../Figurer/Makro/1.32 Økosirk vekst.png')

# %%
plt.clf()

#1 makrodata fra nasjonalregnskapet
df = pd.read_csv('http://data.ssb.no/api/v0/dataset/59012.csv?lang=en', encoding = 'latin1', na_values = '..')
df = df[df['contents'] == 'Current prices, seasonally adjusted (NOK million)']
df.drop('contents',1, inplace =True)
df = df.pivot(index = 'quarter',columns = 'macroeconomic indicator', values = '09190: Final expenditure and gross domestic product, by macroeconomic indicator, contents and quarter')
df.columns = [df.columns.str.split(' ')[i][0] for i in range(len(df.columns))]

df.head()
# Out:
#          bif.nr8307  bif.nr8368  bif.nr83_6  bif.nr83_6fn  bif.nr83_6fnxof  \
# quarter
# 2000K1       3331.0     11613.0     77899.0       57196.0          44682.0
# 2000K2        337.0     11635.0     76499.0       55735.0          42280.0
# 2000K3        328.0     12010.0     72631.0       54656.0          41757.0
# 2000K4        335.0     12532.0     72440.0       55743.0          42904.0
# 2001K1        777.0     13363.0     79944.0       60638.0          46621.0
#
#          bif.nr83indberg  bif.nr83naer  bif.nr83oljroer  bif.nr83rest  \
# quarter
# 2000K1            6211.0       33069.0          14891.0       18780.0
# 2000K2            6158.0       30646.0          14492.0       19200.0
# 2000K3            5823.0       29747.0          13824.0       18806.0
# 2000K4            5335.0       30373.0          13850.0       19825.0
# 2001K1            6337.0       33258.0          14112.0       20641.0
#
#          bif.nr83vare  bif.nr84_5  bif.nr8_  bif.pub8X50A  bil.nr8lu_  \
# quarter
# 2000K1         4748.0     12514.0   81845.0        5812.0      3946.0
# 2000K2         4952.0     13455.0   82997.0        6272.0      6498.0
# 2000K3         4791.0     12899.0   81777.0        4151.0      9147.0
# 2000K4         4877.0     12838.0   82986.0        2847.0     10546.0
# 2001K1         5503.0     14016.0   80842.0        5194.0       898.0
#
#          biv.nr0890  bnpb.nr23_6fn  bnpb.nr23_6fnxof  bnpb.nr23_9  \
# quarter
# 2000K1         27.0       237286.0          180710.0     360266.0
# 2000K2         27.0       238842.0          183129.0     368662.0
# 2000K3         27.0       242973.0          185392.0     383176.0
# 2000K4         27.0       246954.0          188799.0     395011.0
# 2001K1         28.0       255350.0          194492.0     391943.0
#
#          bnpb.nr23_9fn  bnpb.nr23indberg  bnpb.nr23oljsj  bnpb.nr23ptjfn  \
# quarter
# 2000K1        280357.0           33144.0         79909.0        121741.0
# 2000K2        283439.0           34011.0         85222.0        122538.0
# 2000K3        287612.0           34634.0         95564.0        125518.0
# 2000K4        292483.0           34199.0        102528.0        128204.0
# 2001K1        301798.0           35487.0         90146.0        131858.0
#
#          bnpb.nr23vare  bnpb.nr24_5  bnpb.nr29korr  eks.nrskiplfly  \
# quarter
# 2000K1         25825.0      56576.0        43071.0          1901.0
# 2000K2         26580.0      55713.0        44597.0          2227.0
# 2000K3         25239.0      57581.0        44639.0          3663.0
# 2000K4         26397.0      58155.0        45530.0          3364.0
# 2001K1         27147.0      60858.0        46448.0          3449.0
#
#          eks.nrtjen  eks.nrtot  eks.nrtradvare  eks.puboljegs  imp.nrskiplfly  \
# quarter
# 2000K1      36157.0   157495.0         46386.0        73051.0         10729.0
# 2000K2      39567.0   164129.0         49060.0        73275.0          7642.0
# 2000K3      40338.0   178007.0         49880.0        84126.0          6766.0
# 2000K4      43525.0   188722.0         51951.0        89882.0          4202.0
# 2001K1      44540.0   183629.0         51481.0        84159.0          6185.0
#
#          imp.nrtjen  imp.nrtot  imp.nrtradvare  imp.puboljegs  koh.nr61L8  \
# quarter
# 2000K1      32848.0   107539.0         62627.0         1336.0      6858.0
# 2000K2      34938.0   108862.0         65119.0         1162.0      7176.0
# 2000K3      34220.0   109273.0         66484.0         1804.0      6743.0
# 2000K4      36714.0   110420.0         67616.0         1888.0      7185.0
# 2001K1      37785.0   115072.0         69514.0         1587.0      6888.0
#
#          koh.nr61L9  koh.nr61_  koh.nr61tjen  koh.nr61vare  koh.nrpriv  \
# quarter
# 2000K1      -4410.0   151804.0       66196.0       83160.0    158146.0
# 2000K2      -4566.0   153496.0       67066.0       83820.0    160050.0
# 2000K3      -4600.0   154383.0       68249.0       83990.0    161096.0
# 2000K4      -5455.0   154683.0       69231.0       83722.0    161188.0
# 2001K1      -4854.0   158353.0       70269.0       86050.0    165051.0
#
#          koi.nr66_  koo.nr6401  koo.nr64_  koo.nr64sivil  koo.nr65_  \
# quarter
# 2000K1      6342.0      6970.0    27528.0        20558.0    42766.0
# 2000K2      6553.0      6958.0    27798.0        20840.0    42524.0
# 2000K3      6714.0      7001.0    27922.0        20921.0    43620.0
# 2000K4      6505.0      7125.0    28510.0        21385.0    43998.0
# 2001K1      6699.0      7225.0    29633.0        22408.0    47834.0
#
#          koo.nroff  makrok.nrefn  makrok.nreoff  makrok.nrianv  makrok.nrsanv
# quarter
# 2000K1     70294.0      285636.0        82808.0       310311.0       467779.0
# 2000K2     70321.0      286107.0        83776.0       313395.0       477497.0
# 2000K3     71541.0      287294.0        84440.0       314442.0       492422.0
# 2000K4     72508.0      289438.0        85346.0       316709.0       505403.0
# 2001K1     77466.0      303156.0        91483.0       323386.0       506989.0

# %% [markdown]
# <h3>Inntekter</h3>
# <ul>
#     <li>Nasjonalregnskapet/Inntektsregnskapet</li>
# </ul>

# %%
url = 'https://www.ssb.no/statbank/sq/10027772'
df=pd.read_excel(url, skiprows=4, skipfooter=47)
df.index = pd.date_range(start='1/1/2002', end='30/09/2020', freq='Q')
df.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
df.tail(6)
# df.head()
# Out:
#             Inntekter og utgifter. Sesongjustert (mill kr)
# 2019-06-30                                          380187
# 2019-09-30                                          387005
# 2019-12-31                                          396687
# 2020-03-31                                          405602
# 2020-06-30                                          390514
# 2020-09-30                                          385422

# %%
df['Vekst i disponible inntekter'] = np.log(df['Inntekter og utgifter. Sesongjustert (mill kr)']).diff()*100
df['Vekst i disponible inntekter fra året før'] = np.log(df['Inntekter og utgifter. Sesongjustert (mill kr)']).diff(4)*100

# %%
# Fig xx
# df['Disponible inntekter'] = df['Inntekter og utgifter. Sesongjustert (mill kr)']
df['Vekst i disponible inntekter fra året før'].plot()
plt.ylabel('Prosent')
plt.xlabel('Kvartal')
plt.title('Disponible innteker')
plt.legend()
plt.savefig('../Figurer/Makro/99.9 Disp inntekt.png')

# %% [markdown]
# <h3>Varekonsumindeksen</h3>

# %%
# 1B Varekosumindeksen
url = 'http://www.ssb.no/statbank/sq/10025289/'
df_vki = pd.read_excel(url, skiprows=3, skipfooter=50)

# %%
df_vki.index = pd.date_range(start='1/1/2000', end='31/12/2020', freq='M')
# df_vki.drop(df_vki['Unnamed: 0'], axis=1)

df_vki.tail()
# Out:
#            Unnamed: 0  Totalt varekonsum
# 2020-08-31    2020M08              142.6
# 2020-09-30    2020M09              148.3
# 2020-10-31    2020M10              147.0
# 2020-11-30    2020M11              150.0
# 2020-12-31    2020M12              148.4

# %%
df_vki['Totalt varekonsum'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>Pengemarkedsrenter og styringsrente</h2>

# %%
#2 Nibor - abonnement avsluttet, data leveres nå av Finans Norge
# url = 'http://oslobors.no/ob/servlets/excel?type=niborhistory&columns=DATE%2C+CLOSE%2C+CLOSE_DDB%2C+CLOSE_DNM%2C+CLOSE_NDA%2C+CLOSE_SEB%2C+CLOSE_SHB%2C+CLOSE_SWD&format[DATE]=ddd.mm.YY&header[DATE]=Dato&header[CLOSE]=Fixing&header[CLOSE_DDB]=DDB&header[CLOSE_DNM]=DNM&header[CLOSE_NDA]=NDA&header[CLOSE_SEB]=SEB&header[CLOSE_SHB]=SHB&header[CLOSE_SWD]=SWD&view=DELAYED&source=feed.index.nibor.INDICES_FIXING&idrSeource=feed.index.nibor.INDICES_IDR&filter=ITEM_SECTOR%3D%3DsNIBOR{length}M.NIBOR&stop=now&start=1340402400000&space=DAY&ascending=true'

# dic = {}
# for i in ['1','3', '6']:
#     df = pd.read_excel(url.format(length = i))
#     df.index = pd.to_datetime(df.Dato)
#     dic['NIBOR' + ' ' + i + 'M'] = df.mean(axis = 1)
# df = pd.DataFrame(dic)
# df['FOLIO']=1.50
# df["FOLIO"]['2019-09-18':]=1.25
# df["FOLIO"]['2019-08-14':]=1.0
# df["FOLIO"]['2019-03-20':]=0.75
# df['FOLIO']['2018-09-19':]=0.5
# df["FOLIO"]["2016-03-03":]=0.75
# df["FOLIO"]["2015-09-23":]=1.00
# df["FOLIO"]["2015-06-16":]=1.25
# df["FOLIO"]["2014-12-10":]=1.50
# 
# df.head()
# dfses = pd.read_pickle('../dfses.pkl')


url = 'https://www.ssb.no/statbank/sq/10033602'
df_nibor = pd.read_excel(url, skiprows=3, skipfooter=56)
df_nibor.rename(columns={'Unnamed: 0':'Dato'}, inplace=True)
# df_nibor.index = df_nibor.Dato
# df_nibor.drop(['Dato'], axis=1, inplace=True)
df_nibor.rename(columns = {'NIBOR (3 mnd. effektiv)': 'Nibor 3M', 'Norges Banks foliorente (styringsrenten)':'FOLIO'}, inplace=True)

# %%
# Endrer dato til string - bruker str.replace for å erstatte M med -, kan deretter endre til datetime
df_nibor['DatoM'] = df_nibor['Dato'].astype('category')
df_nibor['DatoM'] = df_nibor['DatoM'].str.replace('M', '-')                     
# Endrer til DateTime og periode ÅÅÅÅ-MM:
df_nibor['date']=pd.to_datetime(df_nibor['DatoM']).dt.to_period('M')

# %%
df_nibor.index = df_nibor.date
df_nibor.drop(['DatoM', 'date', 'Dato'], axis=1, inplace=True)

# %%
df_nibor.tail()
# Out:
#          Nibor 3M  FOLIO
# date
# 2020-05      0.28    0.0
# 2020-06      0.37    0.0
# 2020-07      0.28    0.0
# 2020-08      0.23    0.0
# 2020-09      0.28    0.0

# %%
# df['FOLIO'].head(10)

# %%
df_nibor.to_pickle('../dfnibor.pkl')

# %%
df_nibor.plot()
plt.title('3 mnd NIBOR og Foliorenta')
plt.ylabel('Rente i %')
plt.xlabel("")
plt.savefig('2.0 NIBOR.png')

# %%
plt.clf()
plt.title("Rentemargin, NIBOR-FOILO")
df_nibor["MARGIN"]=df_nibor["Nibor 3M"]-df_nibor["FOLIO"]


df_nibor["MARGIN"].plot()
#df['FOLIO'].plot()
plt.savefig('../Figurer/Makro/2.2 Rentemargin.png')
plt.show()

# %% [markdown]
# <h2> Boliglånsrenter </h2>

# %%
# 10738: Renter på nye nedbetalingslån, etter utlånstype, sektor og bindingstid. Utvalg av banker og kredittforetak (prosent)
url = 'https://www.ssb.no/statbank/sq/10033653'
df_renter = pd.read_excel(url, skiprows=4, skipfooter=49)
df_renter.rename(columns = {'Unnamed: 0':'Dato'}, inplace=True)

# Uncomment hvis en skal lage figur med dato (eller plasser etter endring til datetime)
# df_renter.index = df_renter.Dato
# df_renter.drop(columns=['Dato'], inplace=True)

# %%
# Endrer dato til string - bruker str.replace for å erstatte M med -, kan deretter endre til datetime
df_renter['DatoM'] = df_renter['Dato'].astype('category')
df_renter['DatoM'] = df_renter['DatoM'].str.replace('M', '-')                     
# Endrer til DateTime og periode ÅÅÅÅ-MM:
df_renter['date']=pd.to_datetime(df_renter['DatoM']).dt.to_period('M')


df_renter.index = df_renter.date
df_renter.drop(columns=['Dato', 'date', 'DatoM'], inplace=True)

# %%
df_renter.head()
# Out:
#          Nedbetalingslån med pant i bolig
# date
# 2013-12                              4.05
# 2014-01                              4.04
# 2014-02                              4.03
# 2014-03                              4.02
# 2014-04                              4.01

# %%
print(df_renter.head(), df_renter.tail())
# Out:
#          Nedbetalingslån med pant i bolig
# date
# 2013-12                              4.05
# 2014-01                              4.04
# 2014-02                              4.03
# 2014-03                              4.02
# 2014-04                              4.01          Nedbetalingslån med pant i bolig
# date
# 2020-05                              2.02
# 2020-06                              1.97
# 2020-07                              1.95
# 2020-08                              1.94
# 2020-09                              1.92

# %%
df_renter.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df_renters = df_nibor.merge(df_renter, left_on='date', right_on='date')

# %%
# df_renters

# %%
df_renters.plot()
plt.xticks(rotation=45)

# plt.xlabel(rotate='45')
plt.title('Renter')
plt.legend( fancybox=False )
plt.savefig('../Figurer/Makro/renter.png')
plt.show()

# %%
df_renters.corr()
df_renters.head()
# Out:
#          Nibor 3M  FOLIO  MARGIN  Nedbetalingslån med pant i bolig
# date
# 2013-12      1.72    1.5    0.22                              4.05
# 2014-01      1.69    1.5    0.19                              4.04
# 2014-02      1.73    1.5    0.23                              4.03
# 2014-03      1.77    1.5    0.27                              4.02
# 2014-04      1.83    1.5    0.33                              4.01

# %%
import pyodbc 
cnxn_str = ("Driver={SQL Server};"
            "Server=10.232.80.186;"
            "Database=DVSQL;"
            "Trusted_Connection=yes;")

cnxn = pyodbc.connect(cnxn_str)


# cnxn = pyodbc
cursor = cnxn.cursor()

# %%
df_renteBol = pd.read_sql('SELECT * From mart.boliglaansRente order by DatoId' , cnxn)

# %%
# df_renteBol.index = data['dato']
# df_renteBol.drop(columns=['dato', 'produkt','DatoId'], inplace=True)

df_renteBol.head()
# Out:
#      DatoId        dato   produkt  snittRenteBolig
# 0  20170930  2017-09-30  Boliglån         2.496325
# 1  20171031  2017-10-31  Boliglån         2.492837
# 2  20171130  2017-11-30  Boliglån         2.497867
# 3  20171231  2017-12-31  Boliglån         2.489589
# 4  20180131  2018-01-31  Boliglån         2.470414

# %%
df_renteBol['snittRenteBolig'].plot()
plt.show()

# %%
df_renteBol['dato'] = pd.to_datetime(df_renteBol['dato'])
df_renteBol['date'] = df_renteBol['dato'].dt.to_period('M')

df_renteBol.index = df_renteBol['date']
df_renteBol.drop(columns=['dato','produkt','DatoId', 'date'], inplace=True)
df_renteBol.head()
# Out:
#          snittRenteBolig
# date
# 2017-09         2.496325
# 2017-10         2.492837
# 2017-11         2.497867
# 2017-12         2.489589
# 2018-01         2.470414

# %%
df_rentersB = df_renters.merge(df_renteBol, left_on='date', right_on='date')

# %%
df_rentersB['snittRenteBolig_1'] = df_rentersB['snittRenteBolig'].shift(1)

# %%
df_rentersB.tail()
# Out:
#          Nibor 3M  FOLIO  MARGIN  Nedbetalingslån med pant i bolig  \
# date
# 2020-05      0.28    0.0    0.28                              2.02
# 2020-06      0.37    0.0    0.37                              1.97
# 2020-07      0.28    0.0    0.28                              1.95
# 2020-08      0.23    0.0    0.23                              1.94
# 2020-09      0.28    0.0    0.28                              1.92
#
#          snittRenteBolig  snittRenteBolig_1
# date
# 2020-05         2.504943           2.558520
# 2020-06         2.082740           2.504943
# 2020-07         2.067600           2.082740
# 2020-08         2.058067           2.067600
# 2020-09         2.051484           2.058067

# %%
df_rentersB['Nedbetalingslån med pant i bolig'].plot(label="Norske banker")
df_rentersB['snittRenteBolig'].plot(label="BN Bank")
df_rentersB['Nibor 3M'].plot(label='Nibor')
plt.ylabel('Prosent')
plt.xlabel('')
plt.legend()
plt.title('Gjennomsnittlige renter hos BN Bank og de største norske bankene.')
txt  = '''
    Kilde: SSB og BN Bank. Merk at tall fra BN Bank er målt i slutten av måneden,
    mens snittrenter for norske banker er målt midt i måneden.
    '''
plt.savefig('G:/Analyse/Makro/Plot/renter.png')
plt.show()

# %% [markdown]
# # Kreditt
# * https://www.ssb.no/kredind

# %%
url = 'https://www.ssb.no/statbank/sq/10042059'  # sesongjusterte tall
url = 'https://www.ssb.no/statbank/sq/10046976'  # ujusterte tall

# %%
df_k2 = pd.read_excel(url, skiprows=350, skipfooter=52, header=None, names = ['dato', 'husholdninger', 'bedrifter'])

df_k2.index = df_k2['dato']
df_k2.drop(['dato'], axis= 1, inplace=True)

df_k2['Dlog_K2'] = np.log(df_k2['husholdninger']).diff()*100
df_k2['Dlog_K2_12'] = np.log(df_k2['husholdninger']).diff(12)*100

# %%
df_k2.tail(24)
# df_k2.head()
# Out:
#          husholdninger  bedrifter   Dlog_K2  Dlog_K2_12
# dato
# 2019M01        1767231    3473779  0.130628    6.067166
# 2019M02        1782249    3489899  0.846214    5.857048
# 2019M03        1791130    3504347  0.497066    6.138089
# 2019M04        1800574    3519406  0.525880    5.902315
# 2019M05        1807001    3533924  0.356306    5.989626
# 2019M06        1809862    3549604  0.158203    5.923515
# 2019M07        1818547    3559221  0.478723    6.113343
# 2019M08        1833364    3573393  0.811470    6.158193
# 2019M09        1842887    3586467  0.518083    7.464644
# 2019M10        1857165    3600299  0.771777    6.845591
# 2019M11        1857914    3618606  0.040322    6.077729
# 2019M12        1849827    3628907 -0.436223    4.698449
# 2020M01        1861368    3643519  0.621958    5.189779
# 2020M02        1872871    3659525  0.616085    4.959650
# 2020M03        1902920    3673885  1.591700    6.054284
# 2020M04        1902622    3685078 -0.015661    5.512743
# 2020M05        1904338    3693500  0.090151    5.246588
# 2020M06        1900222    3710101 -0.216372    4.872012
# 2020M07        1893288    3725986 -0.365572    4.027717
# 2020M08        1905341    3740124  0.634600    3.850846
# 2020M09        1915467    3757669  0.530046    3.862809
# 2020M10        1923793    3774629  0.433730    3.524763
# 2020M11        1921269    3795988 -0.131285    3.353155
# 2020M12        1920945    3808066 -0.016865    3.772513

# %%
df_k2['Dlog_K2_12'].plot()
df_k2['Dlog_K2'].plot()
plt.show()
#  Noe muffins med vekstratene - de ser ikke ut til å stemme helt med de offisielle tallene til SSB

# %% [markdown]
# <h2>Konsumpriser</h2>

# %%
# KPI og KPI-JAE 
url= 'http://www.ssb.no/statbank/sq/10017630/'

kpi_df = pd.read_excel(url, skiprows=220, skipfooter=82, header=None, names=['Dato', 'KPI', 'KPI-JAE'])
# header = kpi_df.iloc[0]

# header[0]='Dato'
# header[1]='KPI'
# header[2] = 'KPI-JAE'
# # kpi_df = kpi_df[1:] #take the data less the header row
# kpi_df.columns = header

kpi_df.index=kpi_df['Dato']
kpi_df.drop(['Dato'], axis=1, inplace=True)

kpi_df['Dlog_KPI'] = np.log(kpi_df['KPI']).diff()
kpi_df['Dlog_KPI-JAE'] = np.log(kpi_df['KPI-JAE']).diff()
# .astype('int')


#  df.rename(index=str, columns={"A": "a", "B": "c"})

# %%
kpi_df['KPI'].dtype
# Out:
# dtype('float64')

# %%
kpi_df.head()
# Out:
#           KPI  KPI-JAE  Dlog_KPI  Dlog_KPI-JAE
# Dato
# 2003M01  81.9     82.6       NaN           NaN
# 2003M02  81.8     82.8 -0.001222      0.002418
# 2003M03  81.0     82.7 -0.009828     -0.001208
# 2003M04  80.5     82.7 -0.006192      0.000000
# 2003M05  80.1     82.8 -0.004981      0.001208

# %%
kpi_df['log_KPI'] = np.log(kpi_df['KPI'].astype('float'))
kpi_df['log_KPI-JAE'] = np.log(kpi_df['KPI-JAE'].astype('float'))

kpi_df['Dlog_KPI'] = kpi_df['log_KPI'].diff()
kpi_df['Dlog_KPI-JAE'] = kpi_df['log_KPI-JAE'].diff()

kpi_df['DKPI'] = kpi_df['Dlog_KPI']*100
kpi_df['DKPI-JAE'] = kpi_df['Dlog_KPI-JAE']*100

# %%
# header
kpi_df.tail()
# Out:
#            KPI  KPI-JAE  Dlog_KPI  Dlog_KPI-JAE   log_KPI  log_KPI-JAE  \
# Dato
# 2020M06  112.0    111.9  0.000000      0.002685  4.718499     4.717606
# 2020M07  112.4    112.4  0.003565      0.004458  4.722064     4.722064
# 2020M08  112.7    112.8  0.002665      0.003552  4.724729     4.725616
# 2020M09  112.7    112.6  0.000000     -0.001775  4.724729     4.723842
# 2020M10  113.0    112.9  0.002658      0.002661  4.727388     4.726502
#
#              DKPI  DKPI-JAE
# Dato
# 2020M06  0.000000  0.268457
# 2020M07  0.356507  0.445832
# 2020M08  0.266548  0.355240
# 2020M09  0.000000 -0.177462
# 2020M10  0.265840  0.266076

# %%
kpi_df['KPI-JAE, Trend']=kpi_df['DKPI-JAE'].rolling(window=3).mean()

# %%
import datetime
now = datetime.datetime.now()

plt.clf()

# print("Current date and time using str method of datetime object")
# print(str(now))
# print("Current date and time using strftime")
# today=now.strftime("%Y-%d-%m")
# print(today)

kpi_df['KPI'].plot()
kpi_df['KPI-JAE'].plot()
plt.title('KPI')
plt.ylabel('Indeks')
plt.xticks(rotation=45)
plt.xlabel("")
# plt.legend(bbox_to_anchor=(0., -0.15, 1, 0.25), loc=4,
#            ncol=4, mode="expand", borderaxespad=0., fancybox=False )
plt.savefig('../Figurer/Makro/KPI.png')
plt.show()

# %%
kpi_df['DKPI']['2012M10':].plot()
kpi_df['DKPI-JAE']['2012M10':].plot()
kpi_df['KPI-JAE, Trend']['2012M10':].plot()
plt.title('Inflasjon')
plt.ylabel('Prosent')
plt.legend()
plt.xticks(rotation=45)
plt.xlabel("")
# plt.legend(bbox_to_anchor=(0., -0.15, 1, 0.25), loc=4,
#            ncol=4, mode="expand", borderaxespad=0., fancybox=False )
plt.savefig('../Figurer/Makro/DKPI.png')
plt.show()

# %%
df.to_pickle('../df_nibor.pkl')

# %%
start= 'StartPeriod=2011'
url = 'https://data.norges-bank.no/api/data/EXR/B.USD+GBP+EUR.NOK.SP?'+start+'&format=csv-:-comma-true-y'

col_names = ['Dato','EURNOK', 'GBPNOK','USDNOK' ]
df = pd.read_csv(url, sep = ',', names=col_names, header=None)

df = df[9:]
# pd.to_numeric(df['EURNOK'], errors='ignore')

pd.to_datetime(df['Dato'])
df.index=df['Dato']
df.drop(['Dato'], axis=1, inplace=True)

# valuta=['GBPNOK','EURNOK','USDNOK']
# df[valuta].astype('float64', copy=True)
df = df.apply(pd.to_numeric, errors='coerce')

df.apply(pd.to_numeric, errors='coerce').dtypes
# Out:
# EURNOK    float64
# GBPNOK    float64
# USDNOK    float64
# dtype: object

# %%
df.tail()
# Out:
#              EURNOK   GBPNOK  USDNOK
# Dato
# 2020-11-09  10.7101  11.8706  9.0130
# 2020-11-10  10.6618  11.9550  9.0293
# 2020-11-11  10.6773  12.0057  9.0747
# 2020-11-12  10.7658  11.9933  9.1305
# 2020-11-13  10.8123  12.0561  9.1513

# %%
df.to_pickle('../dfvalutaEur.pkl')

# %%
#3 valuta (jeg lager to plot fra denne kategorien for tilpasse størrelsesorden)

df.plot()
plt.xlabel('')
plt.ylabel('NOK')
plt.title('Valutakurser')
plt.savefig('../Figurer/Makro/3.1 valuta.png')

# %%
df.head()
# Out:
#             EURNOK  GBPNOK  USDNOK
# Dato
# 2011-01-03  7.7800   9.033  5.8286
# 2011-01-04  7.8090   9.093  5.8185
# 2011-01-05  7.7895   9.182  5.8953
# 2011-01-06  7.7475   9.174  5.9182
# 2011-01-07  7.7260   9.216  5.9610

# %%
start= 'StartPeriod=2011'
valutaer = 'SEK+TWI+I44'

url = 'https://data.norges-bank.no/api/data/EXR/B.'+valutaer+'.NOK.SP?'+start+'&format=csv-:-comma-true-y'


StartPeriod=2011


col_names = ['Dato', 'I44','SEK','KKI' ]

# %%
df = pd.read_csv(url, sep = ',' , names=col_names, header=None)

df = df[9:]

pd.to_datetime(df['Dato'])
df.index=df['Dato']
df.drop(['Dato'], axis=1, inplace=True)

valutaer = ['SEK','KKI','I44' ]
df[valutaer].astype('float64', copy=True)
df = df.apply(pd.to_numeric, errors='coerce')

df.apply(pd.to_numeric, errors='coerce').dtypes
# Out:
# I44    float64
# SEK    float64
# KKI    float64
# dtype: object

# %%
# df.head()

# %%
plt.clf()
#3.2 valuta
df.plot()
plt.ylabel('NOK')
plt.title('Valutakurser')
plt.savefig('../Figurer/Makro/3.2 valuta.png')

# %%
plt.clf()
#4 ledighet
dfaku = pd.read_csv('http://data.ssb.no/api/v0/dataset/1054.csv?lang=en', names = ['sex', 'age','contents', 'time', 'value'], header = 0)

#cleaning
for i in range(len(dfaku['value'])):
    #df['value'][i] = str(df['value'][i]).replace(',', '.') #change decimalpoint from ',' to '.'
    dfaku['value'][i] = str(dfaku['value'][i]).replace('..','NaN') # change '..' to 'NaN'
    if dfaku['value'][i] == '.' or dfaku['value'][i] == '0':# find missing values as replace with 'NaN'
        dfaku['value'][i] = 'NaN'
        
        
series = pd.Series(dfaku['value'].astype(np.float64))
series.index = [dfaku[dfaku.columns[i]] for i in range(4)]
l = series.index.levels

series[l[0][0], l[1][1], l[2][14]].plot()
plt.xlabel('Dato')
plt.ylabel('Ledighet i %')
plt.title('Ledighet for 15-74 år')
plt.savefig('../Figurer/Makro/4 ledighet.png')
# Out:
# C:\Users\i235jbp\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2877: PerformanceWarning: indexing past lexsort depth may impact performance.
#   raw_cell, store_history, silent, shell_futures)

# %%
dfaku.to_pickle('../dfaku.pkl')

# %%
df_ = dfaku[dfaku['contents']=='Unemployment rate (LFS), seasonally adjusted']
df__ = df_[df_['age']=='15-74 15-74 years']
df_ = df__[df__['sex']=='0 Both sexes']
# df_

# %%
df_aku = df_['value'].astype('float')
df_aku.index = pd.date_range(start='28/02/2006', end='30/09/2020', freq='M')

# %%
plt.style.use('seaborn')
df_aku['2006':].plot()
plt.ylabel('Percent')
plt.savefig('Unemployment.png')
plt.show()
plt.style.use('default')

# %%
# Ledige stillinger
# url=http://www.ssb.no/statbank/sq/10017461/

# %%
# Dagpengemottakere
url = 'https://www.nav.no/no/nav-og-samfunn/statistikk/flere-statistikkomrader/relatert-informasjon/soknader-om-dagpenger/_/attachment/download/6ff7afb2-78d5-410d-a14e-1333ab64db7a:19f3eacf6a0f9fbfe9e7891a2b9fe14b57312d75/1011%20S%C3%B8knader_om_dagpenger.xlsx'
# næringser 
# url = 'https://www.nav.no/no/nav-og-samfunn/statistikk/flere-statistikkomrader/relatert-informasjon/soknader-om-dagpenger/_/attachment/download/45180f2d-4445-4f83-834e-5d8c95d2bf90:120845241b1ca3a76ab8d6b47559f543a743e4f8/2503%20-%20S%C3%B8knader_om_dagpenger._N%C3%A6ring.xlsx'
df_adpm = pd.read_excel(url, skiprows=8, header=None)
df_adpm.drop(columns =[0, 5, 6, 7, 8], inplace=True)
df_adpm.columns=['Dato', 'Søknader', 'Ordinære dagpenger', 'Permitteringer']

df_adpm.index=df_adpm['Dato']
df_adpm.drop(columns=['Dato'], inplace=True)

# %%
df_adpm.tail()
# Out:
#             Søknader  Ordinære dagpenger  Permitteringer
# Dato
# 2020-03-13      9663                1176            8487
# 2020-03-12      1890                 817            1073
# 2020-03-11       770                 504             266
# 2020-03-10       707                 557             150
# 2020-03-09       731                 556             175

# %%
df_adpm.sort_values('Dato', inplace=True)

# %%
df_adpm.plot()
# Out:
# <AxesSubplot:xlabel='Dato'>

# %%
df_adpm['Sum permitteringer'] = df_adpm['Permitteringer'].cumsum()
df_adpm['Sum ordinære dagpenger'] = df_adpm['Ordinære dagpenger'].cumsum()
df_adpm['Sum dagpengesøkere'] = df_adpm['Sum permitteringer']+ df_adpm['Sum ordinære dagpenger']

# %%
plt.style.use('default')
df_adpm['Ordinære dagpenger']['03-12-2020':].plot()
df_adpm['Permitteringer']['03-12-2020':].plot()
df_adpm['Sum permitteringer']['03-12-2020':].plot()
df_adpm['Sum ordinære dagpenger']['03-12-2020':].plot()
df_adpm['Sum dagpengesøkere']['03-12-2020':].plot()

plt.legend()
plt.ylabel('Antall personer')
plt.title('Utvikling i antall dagpengesøkere siden torsdag 12. mars')
plt.savefig('../Figurer/Makro/ledigeCovid.png')
plt.show()

# %%
# NAV og ant arbeidsledige
url = 'https://www.nav.no/no/nav-og-samfunn/statistikk/flere-statistikkomrader/relatert-informasjon/ukentlig-statistikk-over-arbeidsledige/_/attachment/download/301ce315-1ba3-4ac6-b7d2-4b1dedb97e12:932ed3002f295f2749da05ecbea10cb5a3326e6f/1011%20Hovedtall%20om%20arbeidsmarkedet.%20Uke%2046.xlsx'
df_adpmN = pd.read_excel(url, skiprows=1 , skipfooter=10)

# %%
df_adpmN.head()
# Out:
#    Unnamed: 0  Kilde: NAV Hovedtall om arbeidsmarkedet. Uke  Unnamed: 3  \
# 0         NaN         NaN                   Om statistikken         NaN
#
#    Unnamed: 4
# 0         NaN

# %%
#5 boligpris (denne vil jeg skrive om)
df = pd.read_csv('http://data.ssb.no/api/v0/dataset/1060.csv?lang=no', encoding = 'latin1', dtype = object, delimiter = ';')
df.columns = ['region', 'boligtype', 'tid', 'statistikkvariabel', 'prisindeks']
#df['Totalt'] = df['TOTAL Hele landet']

for i in range(len(df['tid'])):
    df['tid'][i] = df['tid'][i][:4] + 'Q' + df['tid'][i][5] #change 'K' to 'Q' in for quarter
    df['prisindeks'][i] = str(df['prisindeks'][i]).replace(',', '.') #change decimalpoint from ',' to '.'
    df['prisindeks'][i] = str(df['prisindeks'][i]).replace('..','NaN') # change '..' to 'NaN'
    if df['prisindeks'][i] == '.' or df['prisindeks'][i] == '0':# find missing values as replace with 'NaN'
        df['prisindeks'][i] = 'NaN'


#reorginaze data in a Series with text variables as multilayered indexes
series = pd.Series(df['prisindeks'].astype(np.float64))#, index = [df[df.columns[i]] for i in range(4)])
series.index = [df[df.columns[i]] for i in range(4)]

# %%
# dfbolig =df
df.to_pickle('../dfbolig.pkl')

# %%
df[df['boligtype']=="00 Boliger i alt"].sample(20)
# Out:
#                                                region         boligtype  \
# 1138                               001 Oslo med Bærum  00 Boliger i alt
# 7525             008 Agder og Rogaland uten Stavanger  00 Boliger i alt
# 8508      009 Møre og Romsdal og Vestland uten Bergen  00 Boliger i alt
# 3825                                    004 Trondheim  00 Boliger i alt
# 6648                                    007 Innlandet  00 Boliger i alt
# 8365      009 Møre og Romsdal og Vestland uten Bergen  00 Boliger i alt
# 5713  006 Vestfold og Telemark og Viken uten Akershus  00 Boliger i alt
# 9336                     010 Trøndelag uten Trondheim  00 Boliger i alt
# 9384                     010 Trøndelag uten Trondheim  00 Boliger i alt
# 82                                  TOTAL Hele landet  00 Boliger i alt
# 7437             008 Agder og Rogaland uten Stavanger  00 Boliger i alt
# 7559             008 Agder og Rogaland uten Stavanger  00 Boliger i alt
# 6477                                    007 Innlandet  00 Boliger i alt
# 4635                          005 Akershus uten Bærum  00 Boliger i alt
# 9359                     010 Trøndelag uten Trondheim  00 Boliger i alt
# 9398                     010 Trøndelag uten Trondheim  00 Boliger i alt
# 4686                          005 Akershus uten Bærum  00 Boliger i alt
# 4677                          005 Akershus uten Bærum  00 Boliger i alt
# 214                                 TOTAL Hele landet  00 Boliger i alt
# 103                                 TOTAL Hele landet  00 Boliger i alt
#
#          tid                            statistikkvariabel prisindeks
# 1138  2019Q2                 Prisindeks for brukte boliger      131.3
# 7525  2012Q3  Prisindeks for brukte boliger, sesongjustert       97.5
# 8508  2020Q3                 Prisindeks for brukte boliger      111.1
# 3825  2010Q1  Prisindeks for brukte boliger, sesongjustert       70.1
# 6648  2018Q1                 Prisindeks for brukte boliger      114.5
# 8365  2002Q3  Prisindeks for brukte boliger, sesongjustert        NaN
# 5713  2016Q1  Prisindeks for brukte boliger, sesongjustert      103.4
# 9336  2009Q1                 Prisindeks for brukte boliger       65.3
# 9384  2015Q1                 Prisindeks for brukte boliger       96.6
# 82    2002Q2                 Prisindeks for brukte boliger       46.4
# 7437  2001Q3  Prisindeks for brukte boliger, sesongjustert        NaN
# 7559  2016Q4  Prisindeks for brukte boliger, sesongjustert       99.3
# 6477  1996Q3  Prisindeks for brukte boliger, sesongjustert        NaN
# 4635  1996Q2  Prisindeks for brukte boliger, sesongjustert        NaN
# 9359  2011Q4  Prisindeks for brukte boliger, sesongjustert       83.5
# 9398  2016Q4                 Prisindeks for brukte boliger      104.5
# 4686  2002Q4                 Prisindeks for brukte boliger       45.7
# 4677  2001Q3  Prisindeks for brukte boliger, sesongjustert        NaN
# 214   2018Q4                 Prisindeks for brukte boliger      112.4
# 103   2004Q4  Prisindeks for brukte boliger, sesongjustert        NaN

# %%
#5.1 boligpris i oslo og bærum
liste = ['TOTAL Hele landet','001 Oslo med Bærum' ]
for i in liste:
    series[i,'00 Boliger i alt',  :, 'Prisindeks for brukte boliger, sesongjustert']['1999Q1':].plot(label = i)
plt.legend()
plt.ylabel('Boligprisindeks')
plt.title('Boligpriser i Oslo inkl. Bærum')
plt.savefig('../Figurer/Makro/5.1 boligpris oslo og landet.png')

# %%
plt.clf()

#5.2 boligprisindeks regioner
# for i in series.index.levels[0][1:-1]:
#     series[i, '00 Boliger i alt', :, 'Prisindeks for brukte boliger, sesongjustert']['1999Q1':].plot(label = i)

liste = ['004 Trondheim', '006 Vestfold og Telemark og Viken uten Akershus', '001 Oslo med Bærum', '003 Bergen', '002 Stavanger']

for i in liste:
    series[i, '00 Boliger i alt', :, 'Prisindeks for brukte boliger, sesongjustert']['2004Q1':].plot(label = i)    
    
    
plt.legend(bbox_to_anchor=(0., -0.35, 1.0, 0.25), loc=4,
           ncol=2, mode="expand", borderaxespad=0., fancybox=False )    
plt.ylabel('Boligprisindeks')
plt.title('Boligpris etter region')
plt.savefig('../Figurer/Makro/5.2 boligprisindeks regioner.png')

# %%
#5.22 boligprisindeks regioner
plt.clf()

liste = ['004 Trondheim', '006 Vestfold og Telemark og Viken uten Akershus', '001 Oslo med Bærum', '003 Bergen', '002 Stavanger']

for i in liste:
    series[i, '00 Boliger i alt', :, 'Prisindeks for brukte boliger, sesongjustert']['2014Q1':].plot(label = i)    
        
#plt.legend()
plt.legend(bbox_to_anchor=(0., -0.3, 1.0, 0.25), loc=4,
           ncol=2, mode="expand", borderaxespad=0., fancybox=False )    
plt.xlabel("")
plt.ylabel('Boligprisindeks')
plt.title('Boligpris etter region, 2014-2019')
plt.savefig('../Figurer/Makro/5.22 boligprisindeks regioner.png')
plt.show()

# %%
# EUROSTAT-- http://appsso.eurostat.ec.europa.eu/nui/show.do?query=BOOKMARK_DS-406779_QID_42D526A3_UID_-3F171EB0&layout=TIME,C,X,0;GEO,L,Y,0;UNIT,L,Z,0;S_ADJ,L,Z,1;NA_ITEM,L,Z,2;INDICATORS,C,Z,3;&zSelection=DS-406779UNIT,CLV10_MEUR;DS-406779INDICATORS,OBS_FLAG;DS-406779S_ADJ,SCA;DS-406779NA_ITEM,B1GQ;&rankName1=UNIT_1_2_-1_2&rankName2=INDICATORS_1_2_-1_2&rankName3=NA-ITEM_1_2_-1_2&rankName4=S-ADJ_1_2_-1_2&rankName5=TIME_1_0_0_0&rankName6=GEO_1_2_0_1&ppcRK=FIRST&ppcSO=ASC&sortC=ASC_-1_FIRST&rStp=&cStp=&rDCh=&cDCh=&rDM=true&cDM=true&footnes=false&empty=false&wai=false&time_mode=ROLLING&time_most_recent=true&lang=EN&cfo=%23%23%23%2C%23%23%23.%23%23%23
#  Ta ut datasett i excel - ta vare på, chainlinked volume, index=100, season and calender adjusted
# On seperate sheets
#http://appsso.eurostat.ec.europa.eu/nui/show.do?query=BOOKMARK_DS-406779_QID_54D3DCA_UID_-3F171EB0&layout=TIME,C,X,0;GEO,L,Y,0;UNIT,L,Z,0;S_ADJ,L,Z,1;NA_ITEM,L,Z,2;INDICATORS,C,Z,3;&zSelection=DS-406779UNIT,CLV10_MEUR;DS-406779INDICATORS,OBS_FLAG;DS-406779S_ADJ,SCA;DS-406779NA_ITEM,B1GQ;&rankName1=UNIT_1_2_-1_2&rankName2=INDICATORS_1_2_-1_2&rankName3=NA-ITEM_1_2_-1_2&rankName4=S-ADJ_1_2_-1_2&rankName5=TIME_1_0_0_0&rankName6=GEO_1_2_0_1&ppcRK=FIRST&ppcSO=ASC&sortC=ASC_-1_FIRST&rStp=&cStp=&rDCh=&cDCh=&rDM=true&cDM=true&footnes=false&empty=false&wai=false&time_mode=ROLLING&time_most_recent=false&lang=EN&cfo=%23%23%23%2C%23%23%23.%23%23%23
euro_df = pd.read_excel(r"C:\Users\i235jbp\Documents\GitHub\Data\Makro\namq_10_gdp.xls", skiprows=9, nan_values=":", skipfooter=3)

euro_df = euro_df.T

new_header = euro_df.iloc[0] #grab the first row for the header
new_header[0]='Time'
euro_df = euro_df[1:] #take the data less the header row
euro_df.columns = new_header


pd.to_datetime(euro_df['Time'])
euro_df.set_index('Time', inplace=True)


# euro_df["Germany"] = euro_df[]
euro_df.rename({'Euro area - 12 countries (2001-2006)':'Euro area', "Germany (until 1990 former territory of the FRG)": 'Germany'}, axis=1, inplace=True)


euro_df.tail()
# Out:
# Unnamed: 0 European Union - 28 countries (2013-2020)  \
# Time
# 2019Q1                                   3.67259e+06
# 2019Q2                                   3.67854e+06
# 2019Q3                                   3.69286e+06
# 2019Q4                                   3.69826e+06
# 2020Q1                                             :
#
# Unnamed: 0 European Union - 15 countries (1995-2004)  \
# Time
# 2019Q1                                   3.34209e+06
# 2019Q2                                   3.34579e+06
# 2019Q3                                   3.35728e+06
# 2019Q4                                   3.36043e+06
# 2020Q1                                       3231233
#
# Unnamed: 0 Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015)  \
# Time
# 2019Q1                                            2.66889e+06
# 2019Q2                                            2.67271e+06
# 2019Q3                                                2680936
# 2019Q4                                            2.68385e+06
# 2020Q1                                            2.58115e+06
#
# Unnamed: 0 Euro area - 19 countries  (from 2015)    Euro area Belgium  \
# Time
# 2019Q1                               2.66889e+06  2.60792e+06  102500
# 2019Q2                               2.67271e+06      2611424  102797
# 2019Q3                                   2680936  2.61924e+06  103215
# 2019Q4                               2.68385e+06      2621716  103713
# 2020Q1                               2.58115e+06  2.52092e+06       :
#
# Unnamed: 0 Bulgaria  Czechia  Denmark Germany Estonia  Ireland   Greece  \
# Time
# 2019Q1      11752.8  47709.5  70651.9  749140  5104.2  73505.5  48155.6
# 2019Q2      11832.1  47945.5  71506.2  747324  5150.3  73195.4  48650.8
# 2019Q3      11910.6  48150.6  71850.1  748791  5210.9  74711.5  48850.5
# 2019Q4      12000.7  48374.4  72254.3  749001  5255.3    76093  48514.6
# 2020Q1            :        :        :       :       :        :        :
#
# Unnamed: 0   Spain  France  Croatia   Italy  Cyprus  Latvia Lithuania  \
# Time
# 2019Q1      294611  557651  12517.1  405004    5296  5918.5    9577.2
# 2019Q2      295732  559337  12594.1  405528  5316.7  5960.8    9660.8
# 2019Q3      296929  560823  12666.5  405801  5344.6  5995.4    9736.8
# 2019Q4      298146  560402  12709.1  404751  5388.4    6003      9840
# 2020Q1      282532  527715        :  385527       :       :    9817.2
#
# Unnamed: 0 Luxembourg  Hungary   Malta Netherlands  Austria  Poland Portugal  \
# Time
# 2019Q1        12784.8  31768.3  2686.2      181111  84851.2  123096  47324.4
# 2019Q2        13026.2  32087.3  2725.7      181703    84826  123927  47560.6
# 2019Q3        13059.4  32455.5  2757.9      182463  84869.3  125428  47707.2
# 2019Q4        13117.5  32771.2  2803.5      183174  84900.6  125670  48064.2
# 2020Q1              :        :       :           :  82785.9       :        :
#
# Unnamed: 0  Romania Slovenia Slovakia Finland  Sweden United Kingdom Iceland  \
# Time
# 2019Q1      43497.7  10676.1        :   51080  112500         549901       :
# 2019Q2      43888.1  10671.6        :   51361  112758         549025       :
# 2019Q3      44149.3    10754        :   51536  113180         551907       :
# 2019Q4      44816.3  10798.3        :   51250  113358         552017       :
# 2020Q1            :        :        :       :       :              :       :
#
# Unnamed: 0   Norway Switzerland Montenegro North Macedonia Albania  Serbia  \
# Time
# 2019Q1      92997.8      127958          :               :       :  9201.3
# 2019Q2      93187.2      128411          :               :       :  9335.5
# 2019Q3      93168.6      128952          :               :       :  9544.7
# 2019Q4      94641.5      129356          :               :       :  9705.3
# 2020Q1            :           :          :               :       :       :
#
# Unnamed: 0 Turkey Bosnia and Herzegovina  \
# Time
# 2019Q1          :                      :
# 2019Q2          :                      :
# 2019Q3          :                      :
# 2019Q4          :                      :
# 2020Q1          :                      :
#
# Unnamed: 0 Kosovo (under United Nations Security Council Resolution 1244/99)  \
# Time
# 2019Q1                                                      :
# 2019Q2                                                      :
# 2019Q3                                                      :
# 2019Q4                                                      :
# 2020Q1                                                      :
#
# Unnamed: 0 Euro area - 18 countries (2014)
# Time
# 2019Q1                                   :
# 2019Q2                                   :
# 2019Q3                                   :
# 2019Q4                                   :
# 2020Q1                                   :

# %%
euro_df.to_pickle('../dfeuro.pkl')
print('Fransk BNP-fall',((527715-560402)/560402*100))
# Out:
# Fransk BNP-fall -5.832777184949375

# %%
# Figur 6.1  BNP fra Eurostat
plt.clf()

(euro_df['Sweden']['2008Q1':'2019Q4']/euro_df['Sweden']['2008Q1']).plot()
(euro_df['United Kingdom']['2008Q1':'2019Q4']/euro_df['United Kingdom']['2008Q1']).plot()
(euro_df['Germany']['2008Q1':'2019Q4']/euro_df['Germany']['2008Q1']).plot()
(euro_df['Spain']['2008Q1':'2020Q1']/euro_df['Spain']['2008Q1']).plot()
(euro_df['France']['2008Q1':'2020Q1']/euro_df['France']['2008Q1']).plot()
(euro_df['Euro area']['2008Q1':'2020Q1']/euro_df['Euro area']['2008Q1']).plot()

plt.title("BNP i Europa, index 2010=100")
plt.legend()
plt.xlabel('BNP-fall i Frankrike 5.8 prosent')
plt.savefig('../Figurer/Makro/6.1 bnp euroområdet.png')
plt.show()

# %%
plt.clf()
# FIG 6.2 PIIGS
(euro_df['Spain']['2006Q1':'2020Q1']/euro_df['Spain']['2008Q1']).plot()
(euro_df["Italy"]['2006Q1':'2020Q1']/euro_df["Italy"]['2008Q1']).plot()
(euro_df["Greece"]['2006Q1':'2019Q4']/euro_df["Greece"]['2008Q1']).plot()
(euro_df["Portugal"]['2006Q1':'2019Q4']/euro_df["Portugal"]['2008Q1']).plot()
(euro_df["Ireland"]['2006Q1':'2019Q4']/euro_df["Ireland"]['2008Q1']).plot()
(euro_df['Euro area']['2006Q1':'2020Q1']/euro_df['Euro area']['2008Q1']).plot()

plt.title("BNP i 'PIIGS', 2008Q1=100")
plt.legend()
plt.savefig('../Figurer/Makro/6.2 bnp PIIGS.png')
plt.show()
# PIIGS - opprinnelig uten italia, men ser at det er den første I'en som går bra og Italia er fortsatt ikke over 2008-nivå, 
# Irland går derimot helt fantastisk - GAFA har boosted BNP??

# %%
plt.clf()
(euro_df['Sweden']['2007Q1':'2019Q4']/euro_df['Sweden']['2008Q1']).plot()
(euro_df['Poland']['2007Q1':'2019Q4']/euro_df['Poland']['2008Q1']).plot()
(euro_df['United Kingdom']['2007Q1':'2019Q4']/euro_df['United Kingdom']['2008Q1']).plot()
(euro_df['Germany']['2007Q1':'2019Q4']/euro_df['Germany']['2008Q1']).plot()
(euro_df['France']['2007Q1':'2020Q1']/euro_df['France']['2008Q1']).plot()
(euro_df['Netherlands']['2007Q1':'2019Q4']/euro_df['Netherlands']['2007Q1']).plot()
plt.title("BNP i Europa, index 2010=100")

plt.legend()
plt.xlabel('Dato')
plt.show()
plt.savefig('6.3 bnp euroområdet.png')

# %%
# http://appsso.eurostat.ec.europa.eu/nui/show.do?query=BOOKMARK_DS-055624_QID_2DC4BB93_UID_-3F171EB0&layout=TIME,C,X,0;GEO,L,Y,0;S_ADJ,L,Z,0;AGE,L,Z,1;UNIT,L,Z,2;SEX,L,Z,3;INDICATORS,C,Z,4;&zSelection=DS-055624SEX,T;DS-055624UNIT,PC_ACT;DS-055624S_ADJ,SA;DS-055624AGE,TOTAL;DS-055624INDICATORS,OBS_FLAG;&rankName1=UNIT_1_2_-1_2&rankName2=AGE_1_2_-1_2&rankName3=INDICATORS_1_2_-1_2&rankName4=SEX_1_2_-1_2&rankName5=S-ADJ_1_2_-1_2&rankName6=TIME_1_0_0_0&rankName7=GEO_1_2_0_1&sortC=ASC_-1_FIRST&rStp=&cStp=&rDCh=&cDCh=&rDM=true&cDM=true&footnes=false&empty=false&wai=false&time_mode=ROLLING&time_most_recent=false&lang=EN&cfo=%23%23%23%2C%23%23%23.%23%23%23

# euroU_df = pd.read_csv(r'C:\Users\i235jbp\Documents\GitHub\une_rt_m.xls',na_values = ':',)
euroU_df = pd.read_excel(r'C:/Users/i235jbp/Documents/GitHub/Data/Makro/une_rt_m.xls', skiprows=10, skipfooter =3, na_values = ':',)
euroU_df = euroU_df.T
header = euroU_df.iloc[0]
header[0]='TIME'
header[11] = 'Germany'

euroU_df = euroU_df[1:]
euroU_df.columns = header
# pd.to_datetime(euroU_df['TIME'])
euroU_df.set_index('TIME', inplace=True)


# euroU_df = euroU_df[euroU_df["S_ADJ"]=="Seasonally adjusted data, not calendar adjusted data"]
# euroU_df = euroU_df[euroU_df["UNIT"]=="Percentage of active population"]
# #dfses.drop('statistikkvariabel',1, inplace=True)
# euroU_df.drop(["UNIT","S_ADJ", "TIME", "SEX", "AGE"], 1, inplace=True)
# #dfses = dfses.pivot(index = 'kvartal', columns = 'makrostørrelse', values = 'Makroøkonomiske hovedstørrelser, etter makrostørrelse, kvartal og statistikkvariabel')
# euroU_df['Value'] = euroU_df['Value'].astype('float64')
# euroU_df = euroU_df.pivot(columns = 'GEO', values="Value")

euroU_df.head()
# Out:
# Unnamed: 0 European Union - 28 countries (2013-2020)  \
# TIME
# 2005M01                                          9.1
# 2005M02                                          9.1
# 2005M03                                          9.1
# 2005M04                                          9.1
# 2005M05                                          9.1
#
# Unnamed: 0 European Union - 25 countries (2004-2006)  \
# TIME
# 2005M01                                          9.1
# 2005M02                                          9.1
# 2005M03                                          9.1
# 2005M04                                          9.2
# 2005M05                                          9.1
#
# Unnamed: 0 Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015)  \
# TIME
# 2005M01                                                     9
# 2005M02                                                     9
# 2005M03                                                   9.1
# 2005M04                                                   9.1
# 2005M05                                                   9.1
#
# Unnamed: 0 Euro area - 19 countries  (from 2015)  \
# TIME
# 2005M01                                      9.2
# 2005M02                                      9.2
# 2005M03                                      9.2
# 2005M04                                      9.2
# 2005M05                                      9.2
#
# Unnamed: 0 Euro area - 18 countries (2014) Belgium Bulgaria Czechia Denmark  \
# TIME
# 2005M01                                9.1     8.3     11.2     8.2     5.3
# 2005M02                                9.2     8.5     10.9     8.1     5.2
# 2005M03                                9.2     8.6     10.6       8     5.2
# 2005M04                                9.2     8.4     10.4       8     5.2
# 2005M05                                9.2     8.6     10.1     7.8       5
#
# Unnamed: 0 Germany (until 1990 former territory of the FRG) Germany Ireland  \
# TIME
# 2005M01                                                10.7     9.2     4.4
# 2005M02                                                10.9     9.3     4.3
# 2005M03                                                10.9     8.6     4.5
# 2005M04                                                11.2     8.3     4.8
# 2005M05                                                11.2       8     4.9
#
# Unnamed: 0 Greece Spain France Croatia Italy Cyprus Latvia Lithuania  \
# TIME
# 2005M01      10.1  10.1    8.7    13.6   7.7    4.9   11.3       9.8
# 2005M02        10   9.9    8.7    13.5   7.9      5     11       9.5
# 2005M03      10.1   9.7    8.7    13.5   7.8    5.2   10.7       9.3
# 2005M04        10   9.7    8.8    13.3   7.9    5.4   10.2       9.3
# 2005M05        10   9.4    8.9    13.3   7.6    5.8   10.1         9
#
# Unnamed: 0 Luxembourg Hungary Malta Netherlands Austria Poland Portugal  \
# TIME
# 2005M01           4.8     6.6   6.7         5.9     5.4   18.1      8.3
# 2005M02           4.8     6.8   6.9           6     5.4   18.2      8.4
# 2005M03           4.7     6.9   7.2           6     5.5   18.3      8.5
# 2005M04           4.7     7.1   7.4           6     5.6   18.4      8.7
# 2005M05           4.7     7.2   7.3           6     5.8   18.4      8.6
#
# Unnamed: 0 Romania Slovenia Slovakia Finland Sweden United Kingdom Iceland  \
# TIME
# 2005M01        7.8      6.4     17.3     8.7      7            4.7     2.9
# 2005M02          8      6.5     17.1     8.6    7.8            4.6     2.8
# 2005M03        7.9      6.4       17     8.5    7.3            4.6     2.7
# 2005M04        7.2      6.1     16.7     8.4    7.6            4.7     2.7
# 2005M05        7.3        6     16.6     8.4    7.9            4.7     2.6
#
# Unnamed: 0 Norway Turkey United States Japan EU27
# TIME
# 2005M01       4.5    9.3           5.3   4.5  NaN
# 2005M02       4.4    9.1           5.4   4.6  NaN
# 2005M03       4.6    9.3           5.2   4.5  NaN
# 2005M04       4.6    9.5           5.2   4.5  NaN
# 2005M05       4.6    9.7           5.1   4.5  NaN

# %%
euroU_df.tail()
# Out:
# Unnamed: 0 European Union - 28 countries (2013-2020)  \
# TIME
# 2019M12                                          6.1
# 2020M01                                          6.1
# 2020M02                                          NaN
# 2020M03                                          NaN
# 2020M04                                          NaN
#
# Unnamed: 0 European Union - 25 countries (2004-2006)  \
# TIME
# 2019M12                                          6.2
# 2020M01                                          6.2
# 2020M02                                          6.2
# 2020M03                                          6.3
# 2020M04                                          NaN
#
# Unnamed: 0 Euro area (EA11-1999, EA12-2001, EA13-2007, EA15-2008, EA16-2009, EA17-2011, EA18-2014, EA19-2015)  \
# TIME
# 2019M12                                                   7.3
# 2020M01                                                   7.3
# 2020M02                                                   7.3
# 2020M03                                                   7.4
# 2020M04                                                   NaN
#
# Unnamed: 0 Euro area - 19 countries  (from 2015)  \
# TIME
# 2019M12                                      7.3
# 2020M01                                      7.3
# 2020M02                                      7.3
# 2020M03                                      7.4
# 2020M04                                      NaN
#
# Unnamed: 0 Euro area - 18 countries (2014) Belgium Bulgaria Czechia Denmark  \
# TIME
# 2019M12                                7.3     5.2      4.2     1.9     4.9
# 2020M01                                7.3     5.2      4.1       2     4.8
# 2020M02                                7.3     5.2        4     1.9     4.8
# 2020M03                                7.4     5.3      4.5       2     4.8
# 2020M04                                NaN     NaN      NaN     NaN     NaN
#
# Unnamed: 0 Germany (until 1990 former territory of the FRG) Germany Ireland  \
# TIME
# 2019M12                                                 3.2     4.4     4.7
# 2020M01                                                 3.2     4.7     4.9
# 2020M02                                                 3.4     4.7     4.8
# 2020M03                                                 3.5     NaN     5.3
# 2020M04                                                 NaN     NaN     5.4
#
# Unnamed: 0 Greece Spain France Croatia Italy Cyprus Latvia Lithuania  \
# TIME
# 2019M12      16.4  13.7    8.2     6.3   9.6    6.3    6.4       6.4
# 2020M01      16.2  13.8    8.1     6.3   9.5    5.9    6.5       6.6
# 2020M02      16.1  13.6    7.9     6.2   9.3    5.8    6.5       6.6
# 2020M03       NaN  14.5    8.4     6.8   8.4    6.7    6.9       7.1
# 2020M04       NaN   NaN    NaN     NaN   NaN    NaN    NaN       NaN
#
# Unnamed: 0 Luxembourg Hungary Malta Netherlands Austria Poland Portugal  \
# TIME
# 2019M12           5.6     3.4   3.3         3.2     4.2    2.9      6.7
# 2020M01           5.6     3.4   3.4           3     4.3    2.9      6.8
# 2020M02           5.7     3.6   3.4         2.9     4.5      3      6.4
# 2020M03           6.5     NaN   3.5         2.9     4.5      3      NaN
# 2020M04           NaN     NaN   NaN         NaN     NaN    NaN      NaN
#
# Unnamed: 0 Romania Slovenia Slovakia Finland Sweden United Kingdom Iceland  \
# TIME
# 2019M12          4      3.8      5.6     6.6    6.6            3.7     3.6
# 2020M01        3.9      3.7      5.4     6.6    7.2            3.8     3.8
# 2020M02        3.9      3.6      5.5     6.5    7.5            NaN     3.8
# 2020M03        4.6      3.8      5.6     6.5    6.7            NaN     NaN
# 2020M04        NaN      NaN      NaN     NaN    NaN            NaN     NaN
#
# Unnamed: 0 Norway Turkey United States Japan EU27
# TIME
# 2019M12       3.9   13.1           3.5   2.2  NaN
# 2020M01       3.7   12.6           3.6   2.4  NaN
# 2020M02       3.5    NaN           3.5   2.4  NaN
# 2020M03       NaN    NaN           4.4   2.5  NaN
# 2020M04       NaN    NaN           NaN   NaN  NaN

# %%
plt.clf()
euroU_df["Spain"]["2007Q1":].plot()
euroU_df["Germany"]["2007Q1":].plot()
euroU_df["France"]["2007Q1":].plot()
euroU_df["United Kingdom"]["2007Q1":].plot()
euroU_df["Poland"]["2007Q1":].plot()
euroU_df["Italy"]["2007Q1":].plot()
plt.title("Arbeidsledighet i prosent av arbeidstilbudet")
plt.legend()
plt.xlabel("Tid")
plt.savefig('../Figurer/Makro/ledighetEuro.png')
plt.show()

# %%
# US renter 
# # Treasury bills
# fsb_url = "https://www.federalreserve.gov/datadownload/Output.aspx?rel=H15&series=efc162fd6c9e30df971fc84ad58a07dd&lastobs=100&from=&to=&filetype=spreadsheetml&label=include&layout=seriescolumn"
# # 3-Month London Interbank Offered Rate (LIBOR), based on U.S. Dollar 
# fred_url = 'https://fred.stlouisfed.org/graph/fredgraph.xls?chart_type=line&recession_bars=on&log_scales=&bgcolor=%23e1e9f0&graph_bgcolor=%23ffffff&fo=Open+Sans&ts=12&tts=12&txtcolor=%23444444&show_legend=yes&show_axis_titles=yes&drp=0&cosd=2013-03-29&coed=2018-03-28&height=450&stacking=&range=Custom&mode=fred&id=USD3MTD156N&transformation=lin&nd=1986-01-02&ost=-99999&oet=99999&lsv=&lev=&mma=0&fml=a&fgst=lin&fgsnd=2009-06-01&fq=Daily&fam=avg&vintage_date=&revision_date=&line_color=%234572a7&line_style=solid&lw=2&scale=left&mark_type=none&mw=2&width=1168'
                        
# fsb_df = pd.read_excel("C:/Users/i235jbp/Documents/GitHub/FRB_3mnd10år_2019februar.xlsx", header = None, skiprows=7, missing = "ND")
fsb_df = pd.read_excel("C:/Users/i235jbp/Documents/GitHub/Data/Makro/FRB_H15.xlsx", header = None, skiprows=7, missing = "ND")

fsb_df.columns = ["Dato",'12mnth action rate','composite yield 10 yrs' ,'3mnth auction bill rate', "LIBOR","T-bill" ,"T-bill-1year","Treasury3year","Treasury10year"]
pd.to_datetime(fsb_df['Dato'])
fsb_df.index = fsb_df.Dato
#fsb_df.drop("Dato", inplace=True)

# %%
fsb_df.tail()
# Out:
#             Dato 12mnth action rate composite yield 10 yrs  \
# Dato
# 2019-12  2019-12                NaN                    NaN
# 2020-01  2020-01                NaN                    NaN
# 2020-02  2020-02                NaN                    NaN
# 2020-03  2020-03                NaN                    NaN
# 2020-04  2020-04                NaN                    NaN
#
#         3mnth auction bill rate  LIBOR  T-bill  T-bill-1year  Treasury3year  \
# Dato
# 2019-12                     NaN    NaN    1.54          1.51           1.63
# 2020-01                     NaN    NaN    1.52          1.49           1.52
# 2020-02                     NaN    NaN    1.52          1.37           1.31
# 2020-03                     NaN    NaN    0.29          0.32           0.50
# 2020-04                     NaN    NaN    0.14          0.18           0.28
#
#          Treasury10year
# Dato
# 2019-12            1.86
# 2020-01            1.76
# 2020-02            1.50
# 2020-03            0.87
# 2020-04            0.66

# %%
# Figur 7.1 - US renter
plt.clf()
#fsb_df["LIBOR"].plot()
fsb_df["T-bill"].plot(label="3mnd T-bill")
# fsb_df["LIBOR"].plot(label="LIBOR")
fsb_df["Treasury3year"].plot(label="Treasury securities 3 år")
fsb_df["Treasury10year"].plot(label="Treasury securities 10 år")
plt.title("Renter, US dollar")
plt.legend()
plt.savefig('../Figurer/Makro/7.1 US renter.png')

# %%
pd.to_datetime(fsb_df['Dato'])
fsb_df['Dato'] = fsb_df['Dato'].datetime.strptime("%Y-%m").strftime("%Y-%m-%d")
fsb_df['2014-02-07':].head()
# fsb_df.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-220-47ac24460a21> in <module>
#       1 pd.to_datetime(fsb_df['Dato'])
# ----> 2 fsb_df['Dato'] = fsb_df['Dato'].datetime.strptime("%Y-%m").strftime("%Y-%m-%d")
#       3 fsb_df['2014-02-07':].head()
#       4 # fsb_df.tail()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'datetime'

# %%
fsb_df.to_pickle('../dffsb.pkl')

# %%
# fred_url = 'https://fred.stlouisfed.org/graph/fredgraph.xls?chart_type=line&recession_bars=on&log_scales=&bgcolor=%23e1e9f0&graph_bgcolor=%23ffffff&fo=Open+Sans&ts=12&tts=12&txtcolor=%23444444&show_legend=yes&show_axis_titles=yes&drp=0&cosd=2013-03-29&coed=2018-03-28&height=450&stacking=&range=Custom&mode=fred&id=USD3MTD156N&transformation=lin&nd=1986-01-02&ost=-99999&oet=99999&lsv=&lev=&mma=0&fml=a&fgst=lin&fgsnd=2009-06-01&fq=Daily&fam=avg&vintage_date=&revision_date=&line_color=%234572a7&line_style=solid&lw=2&scale=left&mark_type=none&mw=2&width=1168'
                        
# fred_df = pd.read_excel(fred_url,  skiprows=10, na_values = "#I/T")
#fred_df = pd.read_excel('G:\Analyse\Makro\Regneark\USD3MTD156N.xls', skiprows=10)
fred_df = pd.read_excel('C:/Users/i235jbp/Documents/GitHub/USD3MTD156N.xls', skiprows=10)
fred_df.columns = ["Dato", "LIBOR"]


fred_df.ffill() # får ikke denne til å fungere
fred_df.index = fred_df.Dato

fred_df.dropna(inplace=True)

# for å ta bort nullere som oppstår pga bank holidays
# fred_df=fred_df[fred_df>0.0]

# %%
fred_df.tail()
# Out:
#                  Dato    LIBOR
# Dato
# 2019-02-01 2019-02-01  2.73263
# 2019-02-04 2019-02-04  2.73438
# 2019-02-05 2019-02-05  2.73850
# 2019-02-06 2019-02-06  2.73763
# 2019-02-07 2019-02-07  2.69700

# %%
fred_df_m = pd.read_excel('C:/Users/i235jbp/Documents/GitHub/USD3MTD156NM.xls', skiprows=10)
fred_df_m.columns = ["Dato", "LIBOR"]

pd.to_datetime(fred_df_m['Dato'])
fred_df_m.index = fred_df_m.Dato

fred_df_m.head()

# %%
# Figur 8.1 - US renter
plt.clf()
#fsb_df["LIBOR"].plot()
fred_df["LIBOR"].plot(label="Eurodollar libor")
#fsb_df["T-bill-1year"].plot(label="1år T-bill")
#fred_df["Treasury3year"].plot(label="Treasure securities 3 år")
plt.title("LIBOR, Eurodollar")
plt.legend()
plt.savefig('../Figurer/Makro/8.1 Eurodollar LIBOR.png')
    
# fred_df['LIBOR']['2017-12-24':'2017-12-31'].plot()
plt.show()

# %%
# result = pd.concat([df1, df4], axis=1, join_axes=[df1.index])
fred_df_m.head()
fsb_df.head()
# nibor_df.head()
# nok_df.head()
# valuta_df.head()
# fsb_df.drop('LIBOR', axis=1, inplace=True)
# renter_df = pd.concat([fred_df, nibor_df, valuta_df], axis=1, join_axes=[fred_df.index])
renter_df = pd.concat([fred_df, valuta], axis=1, join_axes=[fred_df.index])


renter_df.head(8)

# %%
renter_df["LIBOR"].plot(label="Eurodollar libor")
renter_df["T-bill"].plot(label="3mnd T-bill")
#fred_df["Treasury3year"].plot(label="Treasure securities 3 år")
plt.title("LIBOR, Eurodollar og T-bills")
plt.legend()
plt.savefig('8.2 Tbill LIBOR.png')
    
# fred_df['LIBOR']['2017-12-24':'2017-12-31'].plot()
plt.show()

# %%
# Figur 9.1 norske renter og libor
# plt.clf()
# renter_df['LIBOR'].plot()
# renter_df['NIBOR 3M'].plot()
# renter_df['1 USD'].plot(secondary_y=True)
# plt.title("Renter, NOK/USD, 3M NIBOR og LIBOR")
# plt.legend()


# plt.savefig('renteparitet.png')

# fig, ax1 = plt.subplots()

# ax2 = ax1.twinx()
# ax1.plot(renter_df['dato'], renter_df['LIBOR'], 'g-')
# ax2.plot(renter_df['dato'], renter_df['1 USD'] )

# ax1.set_xlabel('X data')
# ax1.set_ylabel('Y1 data', color='g')
# ax2.set_ylabel('Y2 data', color='b')

# plt.show()

# %%
# DEV:

# US - contribution to to growth in GDP 
# Net export: https://fred.stlouisfed.org/series/A019RY2Q224SBEA
# Consumption: https://fred.stlouisfed.org/graph/?g=mZP4
# Public consumption: https://fred.stlouisfed.org/graph/?g=mZP7
# Investment: Gross private inventories: https://fred.stlouisfed.org/graph/?g=mZP9
# Investments: Gross private investments: https://fred.stlouisfed.org/graph/?g=mZPb
# Contributions to percent change in real gross domestic product: Gross private domestic investment: Fixed investment: https://fred.stlouisfed.org/graph/?g=mZPd

# %%
# US savings

# fred_url = 
                        
# fred_df = pd.read_excel(fred_url,  skiprows=10, na_values = "#I/T")
#fred_df = pd.read_excel('G:\Analyse\Makro\Regneark\USD3MTD156N.xls', skiprows=10)
fred_df_s = pd.read_excel('C:/Users/i235jbp/Documents/GitHub/Data/Makro/A072RC1Q156SBEA.xls', skiprows=10)
fred_df_s.columns = ["Dato", "US savings"]
fred_df_s.index = fred_df_s.Dato

# %%
fred_df_s.head()

# %%
# Figur 10.1 - US savings
plt.clf()
fred_df_s["US savings"].plot(label="Sparerate, USA husholdninger")
#fsb_df["T-bill-1year"].plot(label="1år T-bill")
#fred_df["Treasury3year"].plot(label="Treasure securities 3 år")
plt.title("Sparerate i USA, husholdninger")
# plt.legend()
plt.savefig('../Figurer/Makro/10.1 US savings.png')
    
plt.show()

# %%
# US debt to GDP

fred_df_debt = pd.read_excel('C:/Users/i235jbp/Documents/GitHub/Data/Makro/GFDEGDQ188S.xls', skiprows=10)
fred_df_debt.columns = ["Dato", "USDebtToGDP"]
fred_df_debt.index = fred_df_debt.Dato
fred_df_debt.head()

# %%
# Figur 10.2 - US debt to gdp
plt.clf()
fred_df_debt["USDebtToGDP"].plot(label="Sparerate, USA husholdninger")
#fsb_df["T-bill-1year"].plot(label="1år T-bill")
#fred_df["Treasury3year"].plot(label="Treasure securities 3 år")
plt.title("Gjedsgrad i USA, offentlig")
# plt.legend()
plt.savefig('../Figurer/Makro/10.2 US debtratio.png')
    
plt.show()

# %%
#  https://www.nve.no/energiforsyning/kraftmarkedsdata-og-analyser/magasinstatistikk/
el_df = pd.read_excel('C:/Users/i235jbp/Documents/GitHub/Data/Makro/Fyllingsgrad.xlsx', skiprows=2)
# fred_df_debt.columns = ["Dato", "USDebtToGDP"]
# fred_df_debt.index = fred_df_debt.Dato
# fred_df_debt.head()

# %%
el_df.head()
# Out:
#    Iso_uke  Nåværende år       Min    Median      Maks  1995  1996  1997  \
# 0        1      0.640810  0.426842  0.679188  0.787623   NaN   NaN   NaN
# 1        2      0.639191  0.404336  0.656149  0.755858   NaN   NaN   NaN
# 2        3      0.627861  0.386367  0.629205  0.725133   NaN   NaN   NaN
# 3        4      0.621983  0.363698  0.597440  0.692209   NaN   NaN   NaN
# 4        5      0.604162  0.346099  0.567435  0.671378   NaN   NaN   NaN
#
#    1998  1999  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009  \
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    2010  2011  2012  2013  2014  2015  2016  2017  2018      2019  2020  2021
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.624639   NaN   NaN
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.605142   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.575437   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.539403   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  0.504785   NaN   NaN

# %%
# merge year and week column
# el_df['period'] = el_df[['År', 'Uke']].apply(lambda x: ''.join(x), axis=1)
# pd.MultiIndex.from_frame(el_df)
pd.__version__

# %%
# el_df['Hele landet'].plt()
# plt.show()

# %%
df = pd.DataFrame([[11, 22], [13, 23]], columns=['sub_1', 'sub_2'])

# First plot single-header dataframe (headers = ['sub_1', 'sub_2'])
plt.table(cellText=df.round(4).values, cellLoc='center', bbox=[0.225, 1, 0.7, 0.15],
    rowLabels=['  {}  '.format(i) for i in df.index], rowLoc='center',
    rowColours=['silver']*len(df.index), colLabels=df.columns, colLoc='center',
    colColours=['lightgrey']*len(df.columns), colWidths=[0.1]*len(df.columns))

# Then plot a new table with one cell (value = 'main')
plt.table(cellText=[['main']], cellLoc='center', bbox=[0.225, 1.15, 0.7, 0.05],
    cellColours=[['Lavender']])
